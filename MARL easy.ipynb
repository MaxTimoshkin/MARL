# %%
from collections import deque

import random
import pickle
import copy

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
G = nx.Graph()

V = [0, 1, 2, 3, 4, 5, 6, 7]
E = [[0, 1], [0, 5], [1, 2], [1, 4], [2, 3], [3, 4], [2, 7], [4, 5], [5, 6], [4, 6], [4, 7]]

positions = [(0.5, -0.5), (1, 0), (2, 0), (2, 1), (1, 1), (0.5, 0.5), (0, 1), (1.5, 0.5)]

for v in V:
    G.add_node(v, pos=positions[v])

G.add_edges_from(E)

pos = nx.get_node_attributes(G, 'pos')

# %%
nx.draw(G, pos, with_labels=True)
plt.show()

# %%
# Для каждой вершины формируем множество вершин, в которые можно попасть из данной
E_v = [set() for _ in V]

for e in np.concatenate([E, np.flip(E, axis=1)]):
    E_v[e[0]].add(e[1])

E_v = [list(E_v[v]) for v in V]
E_v
# Out:
# [[1, 5],
#  [0, 2, 4],
#  [1, 3, 7],
#  [2, 4],
#  [1, 3, 5, 6, 7],
#  [0, 4, 6],
#  [4, 5],
#  [2, 4]]

# %%
# Находит множество путей в графе из вершины start в вершину end без циклов
def find_paths(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if start not in graph:
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            new_paths = find_paths(graph, node, end, path)
            for new_path in new_paths:
                paths.append(new_path)
    return paths


# Находит множество допустимых вершин для построенного множества путей valid_paths и текущего маршрута current_route
def find_next_vertices(valid_paths, current_route):
    next_vertices = set()

    for path in valid_paths:
        if len(path) > len(current_route) and path[:len(current_route)] == current_route:
            next_vertex = path[len(current_route)]
            next_vertices.add(next_vertex)

    return next_vertices

# %%
# Формирование множеств путей для каждого потока (v_src, v_dst) в графе без циклов
# paths[v_src][v_dst]
paths =  [None] * len(V)
for v_src in range(len(V)):
    paths[v_src] =  [None] * len(V)
    for v_dst in range(len(V)):
        if v_src != v_dst:
            paths[v_src][v_dst] = find_paths(G, v_src, v_dst)

# %%
μ = 1          # Параметр интенсивности обслуживания каждого выходного порта коммутатора
S = 5          # Максимальный размер очереди

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
λ = np.random.rand(len(V), len(V)).round(2) / 2   # Параметры интенсивности каждого потока
np.fill_diagonal(λ, 0)                            # Диагональные элементы не используются
λ
# Out:
# array([[0.   , 0.475, 0.365, 0.3  , 0.08 , 0.08 , 0.03 , 0.435],
#        [0.3  , 0.   , 0.01 , 0.485, 0.415, 0.105, 0.09 , 0.09 ],
#        [0.15 , 0.26 , 0.   , 0.145, 0.305, 0.07 , 0.145, 0.185],
#        [0.23 , 0.395, 0.1  , 0.   , 0.295, 0.025, 0.305, 0.085],
#        [0.035, 0.475, 0.485, 0.405, 0.   , 0.05 , 0.34 , 0.22 ],
#        [0.06 , 0.25 , 0.015, 0.455, 0.13 , 0.   , 0.155, 0.26 ],
#        [0.275, 0.09 , 0.485, 0.39 , 0.47 , 0.445, 0.   , 0.46 ],
#        [0.045, 0.1  , 0.025, 0.165, 0.195, 0.135, 0.415, 0.   ]])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# DQN Agent
class DQNAgent(nn.Module):
    def __init__(self, state_shape, n_actions):
        super().__init__()
        self.n_actions = n_actions
        self.state_shape = state_shape

        self.network = nn.Sequential(
            nn.Linear(state_shape, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions),
        )

    def forward(self, x):
        return self.network(x)

    def get_action(self, state, E_v, E_valid, device=device):
        state_t = torch.tensor(state, device=device, dtype=torch.float32)
        mask = np.zeros(self.n_actions)
        invalid_idxs = [E_v.index(idx) for idx in list(set(E_v) - E_valid)]
        mask[invalid_idxs] = -float("Inf")
        return (self.forward(state_t).detach().cpu().numpy() + mask).argmax()

    def eps_greedy_action(self, state, epsilon, E_v, E_valid, device=device):
        if random.random() < epsilon:
            action = E_v.index(np.random.choice(list(E_valid)))
        else:
            action = self.get_action(state, E_v, E_valid)
        return action


# Replay Buffer
class ReplayBuffer(object):
    def __init__(self, size):
        self._storage = deque(maxlen=size)

    def __len__(self):
        return len(self._storage)

    def add(self, transition):
        self._storage.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self._storage, batch_size)
        states, actions, rewards, next_states = zip(*batch)
        return np.array(states), np.array(actions), np.array(rewards), np.array(next_states)

# %%
state_dim = 4 * len(V) + 2 * len(E)

agents = [None] * len(V)
target_networks = [None] * len(V)

for v in V:
    n_actions = len(E_v[v])
    agents[v] = DQNAgent(state_dim, n_actions).to(device)
    target_networks[v] = DQNAgent(state_dim, n_actions).to(device)
    target_networks[v].load_state_dict(agents[v].state_dict())

optimizers = [torch.optim.Adam(agents[v].parameters(), lr=1e-4) for v in V]
exp_replays = [ReplayBuffer(2000) for v in V]

# %%
# Возвращает temporal difference loss
def compute_td_loss(states, actions, rewards, next_states,
                    agent, target_network, gamma=0.5, device=device):

    states = torch.tensor(states, device=device, dtype=torch.float32)                # shape: [batch_size, state_dim]
    actions = torch.tensor(actions, device=device, dtype=torch.int64)                # shape: [batch_size]
    rewards = torch.tensor(rewards, device=device, dtype=torch.float32)              # shape: [batch_size]
    next_states = torch.tensor(next_states, device=device, dtype=torch.float)        # shape: [batch_size, state_dim]

    predicted_qvalues = agent(states)                                                # shape: [batch_size, n_actions]
    predicted_next_qvalues = target_network(next_states)                             # shape: [batch_size, n_actions]
    predicted_qvalues_for_actions = predicted_qvalues[range(len(actions)), actions]  # shape: [batch_size]
    next_state_values = predicted_next_qvalues.max(axis=1).values
    target_qvalues_for_actions = rewards + gamma * next_state_values
    return torch.mean((predicted_qvalues_for_actions - target_qvalues_for_actions.detach()) ** 2) #loss


# Рассчитывает среднюю длину очереди каждого выходного порта
def loading_queue(ρ, s):
    return np.sum([k * ρ ** (k + 1) for k in range(1, s + 1)], axis=0) / np.sum([(ρ ** k) for k in range(s + 2)], axis=0)


# Возвращает OHE-вектор для потока (v_src, v_dst)
def OHE_thread(v_src, v_dst):
    OHE_n = np.zeros((2, len(V)))
    OHE_n[0, v_src] = 1
    OHE_n[1, v_dst] = 1
    return OHE_n.reshape(-1)


# Рассчитывает epsilon на текущем шаге step
def linear_decay(init_epsilon, final_epsilon, step, decay_steps):
    return max(init_epsilon - step * (init_epsilon - final_epsilon) / decay_steps, final_epsilon)


# Возвращает загруженность L[v] выходных портов q коммутатора v
# основываясь на информации N[v] о поступающих потоках на коммутатор v
def calculate_queues_load(N, v):
    λ_v = np.zeros(len(E_v[v]))
    np.add.at(λ_v, N[v]['q'], λ[N[v]['n'][:, 0], N[v]['n'][:, 1]])
    return loading_queue(λ_v / μ, S) / S


# Принимает загруженности очередей коммутаторов L[v][q]. Возвращает reward
def get_reward(L):
    L_concat = np.concatenate(L)
    return 1 - np.sqrt(((L_concat - L_concat.mean()) ** 2).mean())


# Генерирует потоки в сети: возвращает матрицу размера (T, 3) со столбцами (v_src, v_dst, dt)
def generate_treads(T):
    Times = np.zeros((T, 3), dtype=int)
    Times[:, 0:2] = np.random.randint(0, len(V) - 1, (T, 2))    # v_src, v_dst
    mask = Times[:, 0] == Times[:, 1]

    while np.any(mask):
        Times[:, 0:2][mask] = np.random.randint(0, len(V) - 1, (np.sum(mask), 2))
        mask = Times[:, 0] == Times[:, 1]

    Times[:, 2] = np.random.randint(2, 8, size=T)               # dt
    return Times

# %%
# Гиперпараметры метода DQN

batch_size = 256
total_steps = 50_001

decay_steps = 30_000
init_epsilon = 1
final_epsilon = 0.02

loss_freq = 400
refresh_target_network_freq = 100
eval_freq = 400

max_grad_norm = 50

# %%
# Загруженность оцередей каждого коммутатора L[v][q]
L = [np.zeros(len(E_v[v])) for v in range(len(V))]

# Это тройка массивов [n, q, t] для каждого коммутатора v (содержит информацию о поступающих потоках на коммутаторы), где
#   n = (v_src, v_dst) - потоки, поступающие на коммутатор v;
#   q - выходные порты, на который отправляются пакеты потоков n (0, 1, 2, ...);
#   t - оставшееся время поступления пакетов потоков n.
N = [{'n': np.zeros((0, 2), dtype=np.int32),
      'q': np.zeros(0, dtype=np.int32),
      't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]

Times = generate_treads(total_steps)

# %%
# Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
def update_N(N):
    for v in V:
        N[v]['t'] = N[v]['t'] - 1
        non_zero_idxs = np.where(N[v]['t'] != 0)[0]
        N[v]['n'] = N[v]['n'][non_zero_idxs]
        N[v]['q'] = N[v]['q'][non_zero_idxs]
        N[v]['t'] = N[v]['t'][non_zero_idxs]

# Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
def add_thread_N(N_v, v_src, v_dst, action, dt):
    N_v['n'] = np.vstack([N_v['n'], [v_src, v_dst]])
    N_v['q'] = np.append(N_v['q'], action)
    N_v['t'] = np.append(N_v['t'], dt)

# %% [markdown]
# # Создание валидационной выборки для оценки качества

# %%
# Рассчитывает максимальный ('argmax') или минимальный ('argmin') reward, выбирая оптимальные действия на каждом шаге t
def get_max_min_optimal_reward(Times, optimal='argmax', verbose=False):
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [{'n': np.zeros((0, 2), dtype=np.int32),
           'q': np.zeros(0, dtype=np.int32),
           't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]
    optimal_rewards = []

    T = Times.shape[0]
    for t in range(T):
        v_src, v_dst, dt = Times[t]

        rewards_t = []
        N_t = [copy.deepcopy(N) for _ in range(len(paths[v_src][v_dst]))]
        for i, path in enumerate(paths[v_src][v_dst]):
            for k in range(len(path) - 1):
                # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
                v = path[k]
                action = E_v[v].index(path[k + 1])
                add_thread_N(N_t[i][v], v_src, v_dst, action, dt)

            L = [calculate_queues_load(N_t[i], v) for v in V]
            rewards_t.append(get_reward(L))

        if optimal == 'argmax': best_route = np.argmax(rewards_t)
        if optimal == 'argmin': best_route = np.argmin(rewards_t)
        if verbose:
            print(f"t = {t}\t reward = {round(rewards_t[best_route], 3)}\t route = {paths[v_src][v_dst][best_route]}")
        N = copy.deepcopy(N_t[best_route])
        optimal_rewards.append(rewards_t[best_route])

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N)

        L = [calculate_queues_load(N, v) for v in V]

    return sum(optimal_rewards)

# %%
# Оценивает среднюю награду на валидационной выборке потоков Times (Действия выбираются только жадно)
def evaluate(Times):
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [{'n': np.zeros((0, 2), dtype=np.int32),
          'q': np.zeros(0, dtype=np.int32),
          't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]
    rewards = []

    T = Times.shape[0]
    for t in range(T):
        v_src, v_dst, dt = Times[t]
        v = v_src

        route = []
        while v != v_dst:
            route.append(v)

            # Формирование состояния для подачи на вход нейронке:
            # OHE поступающего потока | Sum OHE всех поступающих потоков на коммутатор | Загруженность во всей сети L
            OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[v]['n']], axis=0)
            state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])

            # Выбор действия жадно
            E_valid = find_next_vertices(paths[v_src][v_dst], route)
            action = agents[v].get_action(state, E_v[v], E_valid)

            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            add_thread_N(N[v], v_src, v_dst, action, dt)

            # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
            L[v] = calculate_queues_load(N, v)

            # Переход на выбранный коммутатор
            v = E_v[v][action]

        # Расчет награды и ее добавление в список
        rewards.append(get_reward(L))

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N)

        L = [calculate_queues_load(N, v) for v in V]

    return sum(rewards) / T

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
T = 100    # t = 0..T, T - общее количество временных шагов
Times_test = generate_treads(T)

max_reward = get_max_min_optimal_reward(Times_test, 'argmax') / T
min_reward = get_max_min_optimal_reward(Times_test, 'argmin') / T

print(f"max reward = {max_reward}")
print(f"min reward = {min_reward}")
# Out:
# max reward = 0.9759624377243478
# min reward = 0.8919704050626504

# %% [markdown]
# # Обучение

# %%
transitions = [[] for _ in V]

PATH = f'/content/drive/MyDrive/marl/2/'
MAX_reward = 0

loss_values = []
reward_values = []

for t in range(total_steps):
    v_src, v_dst, dt = Times[t]
    v = v_src

    route = []
    while v != v_dst:
        route.append(v)

        # Формирование состояния для подачи на вход нейронке:
        # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
        OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[v]['n']], axis=0)
        state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])

        # Выбор действия. eps-жадная стратегия
        E_valid = find_next_vertices(paths[v_src][v_dst], route)
        epsilon = linear_decay(init_epsilon, final_epsilon, t, decay_steps)
        action = agents[v].eps_greedy_action(state, epsilon, E_v[v], E_valid)

        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        add_thread_N(N[v], v_src, v_dst, action, dt)

        # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
        L[v] = calculate_queues_load(N, v)

        if len(transitions[v]) > 0:
            transitions[v].append(state)  #next_state
            exp_replays[v].add(transitions[v])
        transitions[v] = [state, action]

        v = E_v[v][action]

    # Расчет награды и добавление ее в переходы всем агентам маршрута
    reward = get_reward(L)
    for v in route:
        transitions[v].append(reward)

    # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
    update_N(N)

    # Рассчитывает загруженность L[v][q] для каждого выходного порта q коммутатора v
    L = [calculate_queues_load(N, v) for v in V]

    # Обучение каждого коммутатора отдельно
    losses = []
    for v in V:
        if len(exp_replays[v]) >= batch_size:
            states, actions, rewards, next_states = exp_replays[v].sample(batch_size)
            loss = compute_td_loss(states, actions, rewards, next_states, agents[v], target_networks[v])

            loss.backward()
            if t % loss_freq == 0:
                losses.append(loss.data.cpu().item())
            grad_norm = nn.utils.clip_grad_norm_(agents[v].parameters(), max_grad_norm)
            optimizers[v].step()
            optimizers[v].zero_grad()

            # Каждые refresh_target_network_freq обновляются веса ОДНОЙ target сети
            # (Добавляет некоторую стабильность по сравнению с тем, если бы они обновлялись все разом)
            if t % refresh_target_network_freq == 0:
                for v in V:
                    if t % (refresh_target_network_freq * len(V)) == refresh_target_network_freq * v:
                        target_networks[v].load_state_dict(agents[v].state_dict())

    # Вывод лосса с заданной частотой
    if t % loss_freq == 0:
        loss_values.append(losses)
        losses = np.array(losses).round(5)
        print(f"t = {str(t):5}\t losses = {losses}")

    # Вывод масштабированной награды на валидационной выборке с заданной частотой
    if t % eval_freq == 0:
        scaled_reward = (evaluate(Times_test) - min_reward) / (max_reward - min_reward)
        reward_values.append(scaled_reward)
        print(f"t = {str(t):5}\t reward = {round(scaled_reward, 4)}\t eps = {round(epsilon, 4)}\n")

        if scaled_reward > MAX_reward:
            MAX_reward = scaled_reward
            for v in V:
                torch.save(agents[v].state_dict(), PATH + f'model_{v}')
                torch.save(optimizers[v].state_dict(), PATH + f'opt_{v}')
# Out:
# t = 0    	 losses = []
# t = 0    	 reward = 0.327	 eps = 1.0
#
# t = 400  	 losses = [0.57481]
# t = 400  	 reward = 0.3233	 eps = 0.9869
#
# t = 800  	 losses = [0.02598 0.00595 0.01415 0.00383 0.00862]
# t = 800  	 reward = 0.7195	 eps = 0.9739
#
# t = 1200 	 losses = [0.00433 0.00205 0.00288 0.00965 0.17267 0.00095 0.00181 0.01536]
# t = 1200 	 reward = 0.753	 eps = 0.9608
#
# t = 1600 	 losses = [0.00305 0.00161 0.00191 0.00195 0.00128 0.00157 0.00137 0.00237]
# t = 1600 	 reward = 0.804	 eps = 0.9477
#
# t = 2000 	 losses = [0.00133 0.00098 0.00129 0.00127 0.04142 0.00089 0.00069 0.00078]
# t = 2000 	 reward = 0.819	 eps = 0.9347
#
# t = 2400 	 losses = [0.00078 0.00067 0.0007  0.00067 0.00097 0.0009  0.00079 0.00073]
# t = 2400 	 reward = 0.8298	 eps = 0.9216
#
# t = 2800 	 losses = [0.00065 0.00071 0.00089 0.00063 0.00973 0.00049 0.00062 0.00047]
# t = 2800 	 reward = 0.8479	 eps = 0.9085
#
# t = 3200 	 losses = [0.00066 0.00045 0.00048 0.00039 0.00058 0.00063 0.00058 0.00047]
# t = 3200 	 reward = 0.8258	 eps = 0.8955
#
# t = 3600 	 losses = [0.00048 0.0004  0.00053 0.00036 0.00259 0.00045 0.00056 0.00036]
# t = 3600 	 reward = 0.8419	 eps = 0.8824
#
# t = 4000 	 losses = [0.00048 0.00043 0.00038 0.00045 0.00039 0.00047 0.00042 0.00038]
# t = 4000 	 reward = 0.8139	 eps = 0.8693
#
# t = 4400 	 losses = [0.00041 0.00041 0.00033 0.00042 0.00076 0.00028 0.00055 0.00031]
# t = 4400 	 reward = 0.8309	 eps = 0.8563
#
# t = 4800 	 losses = [0.00037 0.00027 0.00027 0.00037 0.00033 0.00027 0.00042 0.00031]
# t = 4800 	 reward = 0.8609	 eps = 0.8432
#
# t = 5200 	 losses = [0.00029 0.00025 0.00021 0.0003  0.00043 0.00033 0.00029 0.00021]
# t = 5200 	 reward = 0.8403	 eps = 0.8301
#
# t = 5600 	 losses = [0.00033 0.00019 0.00024 0.00023 0.00022 0.0003  0.00026 0.00019]
# t = 5600 	 reward = 0.8135	 eps = 0.8171
#
# t = 6000 	 losses = [0.00037 0.00018 0.00029 0.0003  0.00022 0.00025 0.00032 0.00027]
# t = 6000 	 reward = 0.823	 eps = 0.804
#
# t = 6400 	 losses = [0.00025 0.0002  0.0002  0.00025 0.00014 0.00019 0.00028 0.00027]
# t = 6400 	 reward = 0.8438	 eps = 0.7909
#
# t = 6800 	 losses = [0.00022 0.00024 0.00016 0.00025 0.0002  0.00018 0.00035 0.00022]
# t = 6800 	 reward = 0.8663	 eps = 0.7779
#
# t = 7200 	 losses = [0.00028 0.00019 0.00018 0.00017 0.00015 0.00016 0.00021 0.00021]
# t = 7200 	 reward = 0.9023	 eps = 0.7648
#
# t = 7600 	 losses = [0.00029 0.00015 0.00013 0.00026 0.00016 0.00017 0.00023 0.00018]
# t = 7600 	 reward = 0.8396	 eps = 0.7517
#
# t = 8000 	 losses = [0.00019 0.00013 0.00014 0.0002  0.0001  0.0002  0.00021 0.00017]
# t = 8000 	 reward = 0.8492	 eps = 0.7387
#
# t = 8400 	 losses = [0.00026 0.00012 0.00012 0.00021 0.00017 0.00014 0.00021 0.00017]
# t = 8400 	 reward = 0.8331	 eps = 0.7256
#
# t = 8800 	 losses = [0.00017 0.00012 0.00016 0.00022 0.00011 0.00018 0.00023 0.00012]
# t = 8800 	 reward = 0.8515	 eps = 0.7125
#
# t = 9200 	 losses = [2.2e-04 1.1e-04 1.2e-04 1.4e-04 1.4e-04 7.0e-05 1.8e-04 1.3e-04]
# t = 9200 	 reward = 0.8341	 eps = 0.6995
#
# t = 9600 	 losses = [0.00018 0.00014 0.00017 0.00019 0.00011 0.00011 0.0002  0.00013]
# t = 9600 	 reward = 0.7873	 eps = 0.6864
#
# t = 10000	 losses = [1.7e-04 1.0e-04 1.9e-04 1.4e-04 1.2e-04 9.0e-05 2.0e-04 1.6e-04]
# t = 10000	 reward = 0.7749	 eps = 0.6733
#
# t = 10400	 losses = [1.8e-04 1.2e-04 1.5e-04 2.0e-04 8.0e-05 1.2e-04 1.6e-04 2.3e-04]
# t = 10400	 reward = 0.8507	 eps = 0.6603
#
# t = 10800	 losses = [2.0e-04 9.0e-05 1.1e-04 1.5e-04 1.3e-04 7.0e-05 2.3e-04 1.5e-04]
# t = 10800	 reward = 0.8472	 eps = 0.6472
#
# t = 11200	 losses = [1.3e-04 1.1e-04 9.0e-05 1.4e-04 1.1e-04 1.1e-04 1.6e-04 1.1e-04]
# t = 11200	 reward = 0.8591	 eps = 0.6341
#
# t = 11600	 losses = [1.3e-04 9.0e-05 1.1e-04 1.5e-04 1.5e-04 1.2e-04 2.1e-04 1.0e-04]
# t = 11600	 reward = 0.8182	 eps = 0.6211
#
# t = 12000	 losses = [1.7e-04 1.1e-04 1.3e-04 1.7e-04 6.0e-05 1.0e-04 1.7e-04 1.3e-04]
# t = 12000	 reward = 0.8931	 eps = 0.608
#
# t = 12400	 losses = [1.3e-04 8.0e-05 8.0e-05 1.9e-04 1.3e-04 1.0e-04 1.8e-04 1.2e-04]
# t = 12400	 reward = 0.9144	 eps = 0.5949
#
# t = 12800	 losses = [9.0e-05 9.0e-05 6.0e-05 1.1e-04 7.0e-05 6.0e-05 1.9e-04 1.9e-04]
# t = 12800	 reward = 0.8569	 eps = 0.5819
#
# t = 13200	 losses = [1.0e-04 1.0e-04 1.0e-04 1.1e-04 9.0e-05 8.0e-05 1.4e-04 1.2e-04]
# t = 13200	 reward = 0.8581	 eps = 0.5688
#
# t = 13600	 losses = [1.2e-04 1.0e-04 1.1e-04 1.3e-04 8.0e-05 1.0e-04 1.7e-04 1.5e-04]
# t = 13600	 reward = 0.8695	 eps = 0.5557
#
# t = 14000	 losses = [1.9e-04 9.0e-05 1.5e-04 1.3e-04 1.0e-04 7.0e-05 1.5e-04 1.6e-04]
# t = 14000	 reward = 0.8329	 eps = 0.5427
#
# t = 14400	 losses = [1.1e-04 6.0e-05 1.1e-04 1.4e-04 5.0e-05 7.0e-05 1.7e-04 1.8e-04]
# t = 14400	 reward = 0.8247	 eps = 0.5296
#
# t = 14800	 losses = [1.5e-04 8.0e-05 2.6e-04 1.3e-04 1.2e-04 8.0e-05 1.1e-04 1.4e-04]
# t = 14800	 reward = 0.8452	 eps = 0.5165
#
# t = 15200	 losses = [1.2e-04 8.0e-05 1.1e-04 1.2e-04 7.0e-05 1.5e-04 1.0e-04 1.1e-04]
# t = 15200	 reward = 0.8828	 eps = 0.5035
#
# t = 15600	 losses = [1.1e-04 7.0e-05 1.0e-04 1.8e-04 1.0e-04 7.0e-05 1.6e-04 1.4e-04]
# t = 15600	 reward = 0.8774	 eps = 0.4904
#
# t = 16000	 losses = [1.2e-04 8.0e-05 9.0e-05 1.7e-04 8.0e-05 6.0e-05 1.3e-04 1.1e-04]
# t = 16000	 reward = 0.8916	 eps = 0.4773
#
# t = 16400	 losses = [9.0e-05 1.1e-04 9.0e-05 1.2e-04 1.1e-04 1.0e-04 1.3e-04 1.1e-04]
# t = 16400	 reward = 0.878	 eps = 0.4643
#
# t = 16800	 losses = [1.3e-04 7.0e-05 6.0e-05 1.2e-04 6.0e-05 9.0e-05 1.1e-04 1.6e-04]
# t = 16800	 reward = 0.8288	 eps = 0.4512
#
# t = 17200	 losses = [8.0e-05 5.0e-05 8.0e-05 1.9e-04 1.4e-04 9.0e-05 1.2e-04 1.0e-04]
# t = 17200	 reward = 0.8578	 eps = 0.4381
#
# t = 17600	 losses = [1.3e-04 9.0e-05 1.1e-04 1.1e-04 6.0e-05 7.0e-05 1.3e-04 1.4e-04]
# t = 17600	 reward = 0.9035	 eps = 0.4251
#
# t = 18000	 losses = [1.8e-04 5.0e-05 1.0e-04 1.6e-04 1.1e-04 1.7e-04 1.4e-04 1.1e-04]
# t = 18000	 reward = 0.8894	 eps = 0.412
#
# t = 18400	 losses = [1.1e-04 9.0e-05 1.2e-04 1.0e-04 6.0e-05 8.0e-05 1.3e-04 1.3e-04]
# t = 18400	 reward = 0.8806	 eps = 0.3989
#
# t = 18800	 losses = [1.0e-04 8.0e-05 6.0e-05 1.2e-04 1.1e-04 1.3e-04 1.0e-04 1.0e-04]
# t = 18800	 reward = 0.8754	 eps = 0.3859
#
# t = 19200	 losses = [1.4e-04 6.0e-05 6.0e-05 1.2e-04 4.0e-05 9.0e-05 1.2e-04 1.2e-04]
# t = 19200	 reward = 0.8931	 eps = 0.3728
#
# t = 19600	 losses = [1.0e-04 9.0e-05 6.0e-05 1.6e-04 9.0e-05 9.0e-05 1.0e-04 2.0e-04]
# t = 19600	 reward = 0.8399	 eps = 0.3597
#
# t = 20000	 losses = [1.0e-04 8.0e-05 1.0e-04 1.1e-04 6.0e-05 9.0e-05 1.3e-04 1.1e-04]
# t = 20000	 reward = 0.844	 eps = 0.3467
#
# t = 20400	 losses = [1.1e-04 7.0e-05 1.0e-04 1.2e-04 1.0e-04 1.0e-04 1.5e-04 1.2e-04]
# t = 20400	 reward = 0.9152	 eps = 0.3336
#
# t = 20800	 losses = [8.0e-05 7.0e-05 8.0e-05 1.1e-04 7.0e-05 1.2e-04 1.2e-04 1.1e-04]
# t = 20800	 reward = 0.8573	 eps = 0.3205
#
# t = 21200	 losses = [1.2e-04 8.0e-05 8.0e-05 1.3e-04 8.0e-05 8.0e-05 1.2e-04 1.4e-04]
# t = 21200	 reward = 0.8688	 eps = 0.3075
#
# t = 21600	 losses = [9.0e-05 6.0e-05 6.0e-05 1.2e-04 5.0e-05 9.0e-05 1.0e-04 9.0e-05]
# t = 21600	 reward = 0.8533	 eps = 0.2944
#
# t = 22000	 losses = [9.0e-05 8.0e-05 7.0e-05 1.2e-04 8.0e-05 6.0e-05 1.2e-04 1.0e-04]
# t = 22000	 reward = 0.843	 eps = 0.2813
#
# t = 22400	 losses = [1.5e-04 9.0e-05 5.0e-05 1.0e-04 9.0e-05 9.0e-05 1.5e-04 9.0e-05]
# t = 22400	 reward = 0.8557	 eps = 0.2683
#
# t = 22800	 losses = [1.2e-04 6.0e-05 1.1e-04 9.0e-05 9.0e-05 5.0e-05 1.2e-04 1.2e-04]
# t = 22800	 reward = 0.8572	 eps = 0.2552
#
# t = 23200	 losses = [7.0e-05 6.0e-05 5.0e-05 9.0e-05 4.0e-05 8.0e-05 1.1e-04 9.0e-05]
# t = 23200	 reward = 0.905	 eps = 0.2421
#
# t = 23600	 losses = [9.0e-05 7.0e-05 1.0e-04 1.1e-04 9.0e-05 6.0e-05 1.1e-04 1.1e-04]
# t = 23600	 reward = 0.8967	 eps = 0.2291
#
# t = 24000	 losses = [8.0e-05 7.0e-05 8.0e-05 8.0e-05 6.0e-05 1.2e-04 1.2e-04 1.1e-04]
# t = 24000	 reward = 0.9092	 eps = 0.216
#
# t = 24400	 losses = [1.3e-04 5.0e-05 6.0e-05 1.0e-04 9.0e-05 7.0e-05 1.0e-04 9.0e-05]
# t = 24400	 reward = 0.8469	 eps = 0.2029
#
# t = 24800	 losses = [8.e-05 4.e-05 7.e-05 1.e-04 6.e-05 6.e-05 1.e-04 7.e-05]
# t = 24800	 reward = 0.9027	 eps = 0.1899
#
# t = 25200	 losses = [1.0e-04 4.0e-05 5.0e-05 1.2e-04 1.0e-04 7.0e-05 1.2e-04 1.1e-04]
# t = 25200	 reward = 0.8359	 eps = 0.1768
#
# t = 25600	 losses = [8.0e-05 5.0e-05 9.0e-05 1.0e-04 5.0e-05 6.0e-05 1.5e-04 8.0e-05]
# t = 25600	 reward = 0.8714	 eps = 0.1637
#
# t = 26000	 losses = [1.0e-04 5.0e-05 7.0e-05 1.0e-04 1.0e-04 5.0e-05 1.3e-04 1.0e-04]
# t = 26000	 reward = 0.8714	 eps = 0.1507
#
# t = 26400	 losses = [1.0e-04 4.0e-05 4.0e-05 8.0e-05 5.0e-05 4.0e-05 1.1e-04 1.5e-04]
# t = 26400	 reward = 0.8719	 eps = 0.1376
#
# t = 26800	 losses = [9.0e-05 7.0e-05 6.0e-05 1.4e-04 7.0e-05 5.0e-05 1.1e-04 9.0e-05]
# t = 26800	 reward = 0.8572	 eps = 0.1245
#
# t = 27200	 losses = [1.1e-04 5.0e-05 1.0e-04 8.0e-05 4.0e-05 6.0e-05 1.3e-04 9.0e-05]
# t = 27200	 reward = 0.9134	 eps = 0.1115
#
# t = 27600	 losses = [1.e-04 7.e-05 6.e-05 9.e-05 7.e-05 6.e-05 7.e-05 9.e-05]
# t = 27600	 reward = 0.8979	 eps = 0.0984
#
# t = 28000	 losses = [1.2e-04 7.0e-05 7.0e-05 1.1e-04 6.0e-05 9.0e-05 9.0e-05 7.0e-05]
# t = 28000	 reward = 0.9151	 eps = 0.0853
#
# t = 28400	 losses = [9.e-05 9.e-05 6.e-05 1.e-04 7.e-05 6.e-05 9.e-05 8.e-05]
# t = 28400	 reward = 0.9173	 eps = 0.0723
#
# t = 28800	 losses = [1.1e-04 5.0e-05 7.0e-05 1.0e-04 4.0e-05 5.0e-05 7.0e-05 7.0e-05]
# t = 28800	 reward = 0.9232	 eps = 0.0592
#
# t = 29200	 losses = [1.e-04 5.e-05 6.e-05 9.e-05 6.e-05 5.e-05 1.e-04 1.e-04]
# t = 29200	 reward = 0.943	 eps = 0.0461
#
# t = 29600	 losses = [9.e-05 7.e-05 5.e-05 9.e-05 3.e-05 5.e-05 8.e-05 9.e-05]
# t = 29600	 reward = 0.9161	 eps = 0.0331
#
# t = 30000	 losses = [8.e-05 7.e-05 8.e-05 8.e-05 9.e-05 6.e-05 1.e-04 7.e-05]
# t = 30000	 reward = 0.8935	 eps = 0.02
#
# t = 30400	 losses = [1.e-04 6.e-05 5.e-05 1.e-04 2.e-05 9.e-05 1.e-04 6.e-05]
# t = 30400	 reward = 0.8762	 eps = 0.02
#
# t = 30800	 losses = [1.e-04 5.e-05 7.e-05 1.e-04 6.e-05 6.e-05 9.e-05 8.e-05]
# t = 30800	 reward = 0.9208	 eps = 0.02
#
# t = 31200	 losses = [1.e-04 8.e-05 5.e-05 1.e-04 3.e-05 6.e-05 8.e-05 1.e-04]
# t = 31200	 reward = 0.913	 eps = 0.02
#
# t = 31600	 losses = [6.e-05 5.e-05 5.e-05 9.e-05 7.e-05 6.e-05 1.e-04 8.e-05]
# t = 31600	 reward = 0.8382	 eps = 0.02
#
# t = 32000	 losses = [1.1e-04 4.0e-05 3.0e-05 8.0e-05 4.0e-05 5.0e-05 1.3e-04 8.0e-05]
# t = 32000	 reward = 0.9397	 eps = 0.02
#
# t = 32400	 losses = [5.e-05 5.e-05 6.e-05 8.e-05 6.e-05 5.e-05 1.e-04 6.e-05]
# t = 32400	 reward = 0.8936	 eps = 0.02
#
# t = 32800	 losses = [8.e-05 6.e-05 7.e-05 1.e-04 3.e-05 6.e-05 9.e-05 5.e-05]
# t = 32800	 reward = 0.8852	 eps = 0.02
#
# t = 33200	 losses = [6.e-05 4.e-05 5.e-05 1.e-04 5.e-05 5.e-05 9.e-05 6.e-05]
# t = 33200	 reward = 0.878	 eps = 0.02
#
# t = 33600	 losses = [7.e-05 4.e-05 4.e-05 7.e-05 4.e-05 7.e-05 8.e-05 5.e-05]
# t = 33600	 reward = 0.9287	 eps = 0.02
#
# t = 34000	 losses = [5.e-05 5.e-05 4.e-05 9.e-05 6.e-05 6.e-05 6.e-05 5.e-05]
# t = 34000	 reward = 0.9123	 eps = 0.02
#
# t = 34400	 losses = [8.0e-05 5.0e-05 7.0e-05 1.4e-04 3.0e-05 6.0e-05 9.0e-05 9.0e-05]
# t = 34400	 reward = 0.886	 eps = 0.02
#
# t = 34800	 losses = [6.e-05 5.e-05 6.e-05 8.e-05 5.e-05 7.e-05 7.e-05 6.e-05]
# t = 34800	 reward = 0.8768	 eps = 0.02
#
# t = 35200	 losses = [5.e-05 4.e-05 5.e-05 1.e-04 4.e-05 5.e-05 8.e-05 7.e-05]
# t = 35200	 reward = 0.9122	 eps = 0.02
#
# t = 35600	 losses = [4.e-05 4.e-05 4.e-05 9.e-05 7.e-05 6.e-05 7.e-05 5.e-05]
# t = 35600	 reward = 0.8978	 eps = 0.02
#
# t = 36000	 losses = [5.0e-05 5.0e-05 6.0e-05 1.1e-04 4.0e-05 5.0e-05 7.0e-05 8.0e-05]
# t = 36000	 reward = 0.9074	 eps = 0.02
#
# t = 36400	 losses = [5.e-05 4.e-05 6.e-05 9.e-05 6.e-05 4.e-05 7.e-05 6.e-05]
# t = 36400	 reward = 0.9209	 eps = 0.02
#
# t = 36800	 losses = [6.e-05 4.e-05 4.e-05 6.e-05 3.e-05 7.e-05 7.e-05 6.e-05]
# t = 36800	 reward = 0.9044	 eps = 0.02
#
# t = 37200	 losses = [7.e-05 4.e-05 5.e-05 5.e-05 7.e-05 5.e-05 5.e-05 5.e-05]
# t = 37200	 reward = 0.9041	 eps = 0.02
#
# t = 37600	 losses = [5.e-05 6.e-05 4.e-05 1.e-04 4.e-05 5.e-05 9.e-05 5.e-05]
# t = 37600	 reward = 0.8781	 eps = 0.02
#
# t = 38000	 losses = [5.e-05 5.e-05 4.e-05 5.e-05 4.e-05 5.e-05 7.e-05 6.e-05]
# t = 38000	 reward = 0.943	 eps = 0.02
#
# t = 38400	 losses = [4.e-05 4.e-05 5.e-05 4.e-05 3.e-05 5.e-05 9.e-05 4.e-05]
# t = 38400	 reward = 0.9166	 eps = 0.02
#
# t = 38800	 losses = [1.1e-04 6.0e-05 5.0e-05 6.0e-05 7.0e-05 4.0e-05 7.0e-05 7.0e-05]
# t = 38800	 reward = 0.9301	 eps = 0.02
#
# t = 39200	 losses = [5.e-05 5.e-05 5.e-05 6.e-05 3.e-05 6.e-05 7.e-05 6.e-05]
# t = 39200	 reward = 0.9278	 eps = 0.02
#
# t = 39600	 losses = [5.e-05 4.e-05 4.e-05 8.e-05 7.e-05 4.e-05 8.e-05 6.e-05]
# t = 39600	 reward = 0.9353	 eps = 0.02
#
# t = 40000	 losses = [5.e-05 5.e-05 4.e-05 5.e-05 2.e-05 4.e-05 6.e-05 6.e-05]
# t = 40000	 reward = 0.9037	 eps = 0.02
#
# t = 40400	 losses = [8.e-05 4.e-05 4.e-05 6.e-05 7.e-05 9.e-05 6.e-05 7.e-05]
# t = 40400	 reward = 0.9315	 eps = 0.02
#
# t = 40800	 losses = [5.e-05 5.e-05 4.e-05 6.e-05 2.e-05 5.e-05 6.e-05 7.e-05]
# t = 40800	 reward = 0.9153	 eps = 0.02
#
# t = 41200	 losses = [5.e-05 4.e-05 4.e-05 6.e-05 6.e-05 5.e-05 6.e-05 4.e-05]
# t = 41200	 reward = 0.9211	 eps = 0.02
#
# t = 41600	 losses = [5.e-05 4.e-05 4.e-05 6.e-05 3.e-05 4.e-05 6.e-05 7.e-05]
# t = 41600	 reward = 0.9137	 eps = 0.02
#
# t = 42000	 losses = [8.e-05 5.e-05 5.e-05 6.e-05 5.e-05 4.e-05 6.e-05 5.e-05]
# t = 42000	 reward = 0.9498	 eps = 0.02
#
# t = 42400	 losses = [6.e-05 7.e-05 5.e-05 7.e-05 3.e-05 3.e-05 7.e-05 6.e-05]
# t = 42400	 reward = 0.8863	 eps = 0.02
#
# t = 42800	 losses = [6.e-05 8.e-05 6.e-05 6.e-05 5.e-05 5.e-05 4.e-05 6.e-05]
# t = 42800	 reward = 0.894	 eps = 0.02
#
# t = 43200	 losses = [6.e-05 3.e-05 5.e-05 7.e-05 2.e-05 4.e-05 1.e-04 4.e-05]
# t = 43200	 reward = 0.9003	 eps = 0.02
#
# t = 43600	 losses = [8.e-05 4.e-05 4.e-05 6.e-05 5.e-05 5.e-05 5.e-05 4.e-05]
# t = 43600	 reward = 0.9277	 eps = 0.02
#
# t = 44000	 losses = [7.e-05 4.e-05 5.e-05 5.e-05 3.e-05 5.e-05 6.e-05 5.e-05]
# t = 44000	 reward = 0.8848	 eps = 0.02
#
# t = 44400	 losses = [8.e-05 4.e-05 4.e-05 6.e-05 9.e-05 4.e-05 5.e-05 7.e-05]
# t = 44400	 reward = 0.9353	 eps = 0.02
#
# t = 44800	 losses = [7.e-05 4.e-05 5.e-05 9.e-05 4.e-05 5.e-05 7.e-05 5.e-05]
# t = 44800	 reward = 0.9195	 eps = 0.02
#
# t = 45200	 losses = [6.e-05 7.e-05 4.e-05 1.e-04 6.e-05 5.e-05 8.e-05 6.e-05]
# t = 45200	 reward = 0.9303	 eps = 0.02
#
# t = 45600	 losses = [6.e-05 4.e-05 3.e-05 6.e-05 3.e-05 5.e-05 8.e-05 5.e-05]
# t = 45600	 reward = 0.9506	 eps = 0.02
#
# t = 46000	 losses = [7.e-05 4.e-05 3.e-05 6.e-05 6.e-05 5.e-05 5.e-05 7.e-05]
# t = 46000	 reward = 0.926	 eps = 0.02
#
# t = 46400	 losses = [4.e-05 4.e-05 3.e-05 5.e-05 3.e-05 6.e-05 8.e-05 4.e-05]
# t = 46400	 reward = 0.9343	 eps = 0.02
#
# t = 46800	 losses = [4.e-05 6.e-05 4.e-05 4.e-05 5.e-05 5.e-05 6.e-05 7.e-05]
# t = 46800	 reward = 0.9542	 eps = 0.02
#
# t = 47200	 losses = [6.e-05 4.e-05 5.e-05 4.e-05 3.e-05 7.e-05 5.e-05 5.e-05]
# t = 47200	 reward = 0.9563	 eps = 0.02
#
# t = 47600	 losses = [8.e-05 5.e-05 3.e-05 5.e-05 6.e-05 5.e-05 7.e-05 5.e-05]
# t = 47600	 reward = 0.9224	 eps = 0.02
#
# t = 48000	 losses = [5.e-05 3.e-05 4.e-05 5.e-05 3.e-05 4.e-05 7.e-05 6.e-05]
# t = 48000	 reward = 0.9565	 eps = 0.02
#
# t = 48400	 losses = [5.e-05 4.e-05 4.e-05 4.e-05 5.e-05 4.e-05 6.e-05 5.e-05]
# t = 48400	 reward = 0.9284	 eps = 0.02
#
# t = 48800	 losses = [6.e-05 3.e-05 5.e-05 5.e-05 3.e-05 7.e-05 5.e-05 6.e-05]
# t = 48800	 reward = 0.9473	 eps = 0.02
#
# t = 49200	 losses = [6.e-05 4.e-05 4.e-05 4.e-05 5.e-05 6.e-05 5.e-05 4.e-05]
# t = 49200	 reward = 0.9273	 eps = 0.02
#
# t = 49600	 losses = [5.0e-05 3.0e-05 6.0e-05 5.0e-05 2.0e-05 4.0e-05 5.0e-05 1.1e-04]
# t = 49600	 reward = 0.951	 eps = 0.02
#
# t = 50000	 losses = [6.e-05 2.e-05 3.e-05 5.e-05 5.e-05 7.e-05 6.e-05 6.e-05]
# t = 50000	 reward = 0.9508	 eps = 0.02

# %%
#Соранение списки rewards & losses

with open(f'{PATH}data.pickle', 'wb') as f:
   pickle.dump((reward_values, loss_values), f)

# %% [markdown]
# # Построение графиков зависимостей $r(t)$, $Loss(t)$

# %%
x = range(0, total_steps, eval_freq)

plt.figure(figsize=(12, 8))
plt.title('График зависимости масштабированной награды от времени')
plt.xlabel('t')
plt.ylabel('r(t)')
plt.grid()
plt.ylim([0, 1])
plt.plot(x, reward_values)
plt.show()

# %%
n_delete = 3  # Начинаем с индекса 3, так как ранее не для всех агентов еще был рассчитан loss
loss_values = np.array(loss_values[n_delete:]).T
x = range(n_delete*loss_freq, total_steps, loss_freq)

plt.figure(figsize=(12, 8))
plt.grid()
plt.ylim([0, 0.0025])
plt.title('График зависимости loss от времени')
plt.xlabel('t')
plt.ylabel('loss(t)')

for i, loss in enumerate(loss_values):
    plt.plot(x, loss, label=f'Agent {i+1}')

plt.legend()
plt.show()

# %%
log_losses = np.log(loss_values)

plt.figure(figsize=(12, 8))
plt.grid()
plt.ylim([-11, -4])
plt.title('График зависимости loss(t) в логарифмическом масштабе')
plt.xlabel('t')
plt.ylabel('loss(t)')

for i, losses in enumerate(log_losses):
    plt.plot(x, losses, label=f'Agent {i+1}')

plt.legend()
plt.show()

# %% [markdown]
# #Визуализация графа сети

# %%
# Визуализирует текущее состояние сети. Принимает на вход граф G, информацию о поступающих потоках N.
# Есть возможность выделить маршрут отдельного потока selected_thread=[v_src, v_dst], передав его третьим аргументом
def visualize(G, N, selected_thread=None):
    G = G.to_directed()
    L = [calculate_queues_load(N, v) for v in V]

    # --- Вершины ---
    for u, v in G.edges:
        G[u][v]['weight'] = 0

    # --- Веса вершин ---
    for v_src in V:
        for v_dst in E_v[v_src]:
            G[v_src][v_dst]['weight'] = round(L[v_src][E_v[v_src].index(v_dst)], 3)

    # --- Цвета ---
    for u, v in G.edges:
        G[u][v]['color'] = 'black'

    # --- Выделение маршрута selected_thread ---
    if selected_thread is not None:
        for v_src in V:
            idxs = np.where(np.all(N[v_src]['n'] == selected_thread, axis=1))[0]
            idxs_dst = N[v_src]['q'][idxs]
            for v_dst in np.array(E_v[v_src])[idxs_dst]:
                G[v_src][v_dst]['color'] = 'y'
                G[v_dst][v_src]['color'] = 'y'

    # --- Списки вершин и цветов ---
    colors = nx.get_edge_attributes(G, 'color').values()
    weights = nx.get_edge_attributes(G, 'weight')

    # --- Вывод информации о потоках ---
    print("Текущие потоки в сети:")
    all_n = np.vstack([N[v]['n'] for v in V])
    for (v_src, v_dst) in np.unique(all_n, axis=0):
        print(f"Поток = ({v_src} -> {v_dst}), L = {round(loading_queue(λ[v_src, v_dst] / μ, S) / S, 3)}")

    print()
    if selected_thread is not None:
        v_src, v_dst = selected_thread
        print(f'Выделенный поток = ({v_src} -> {v_dst}), L = {round(loading_queue(λ[v_src, v_dst] / μ, S) / S, 3)}')
    print(f"L_mean = {round(np.concatenate(L).mean(), 4)}, reward = {round(get_reward(L), 4)}")

    # --- Визуализация графа ---
    nx.draw(G, pos, with_labels=True, edge_color=colors)
    nx.draw_networkx_edge_labels(G, pos, weights, label_pos=0.66)
    plt.show()

# %% [markdown]
# # Тестирование и анализ обученных агентов на новой выборке потоков

# %%
# Загрузка сохраненных моделей и параметров оптимизаторов
PATH = f'/content/drive/MyDrive/marl/2/'

for v in V:
    agents[v].load_state_dict(torch.load(PATH + f'model_{v}'))
    optimizers[v].load_state_dict(torch.load(PATH + f'opt_{v}'))

# %%
# with open(f'{PATH}data.pickle', 'rb') as f:
#     data_new = pickle.load(f)

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
T = 100    # t = 0..T, T - общее количество временных шагов
Times_test = generate_treads(T)

# %%
# Создает массив N(t), сохраняющий поступающие потоки в каждый момент времени t, для анализа

L = [np.zeros(len(E_v[v])) for v in range(len(V))]
N = [[{'n': np.zeros((0, 2), dtype=np.int32),
       'q': np.zeros(0, dtype=np.int32),
       't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))] for _ in range(T)]

transitions = [[] for _ in V]
rewards = []

for t in range(T):
    print(f"t = {t}, thread = {Times_test[t][0:2]}", end='\t')
    v_src, v_dst, dt = Times_test[t]

    route = []
    v = v_src
    while v != v_dst:
        route.append(v)

        # Формирование состояния для подачи на вход нейронке:
        # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
        OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[t][v]['n']], axis=0)
        state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])

        # Выбор действия жадно
        E_valid = find_next_vertices(paths[v_src][v_dst], route)
        action = agents[v].get_action(state, E_v[v], E_valid)

        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        add_thread_N(N[t][v], v_src, v_dst, action, dt)

        # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
        L[v] = calculate_queues_load(N[t], v)

        v = E_v[v][action]

    # Расчет награды и возвращение ее в переходы всем агентам
    reward = get_reward(L)
    print(f"reward = {round(reward, 4)}", end='\t')
    print(f"route = {route}", end='\t')
    rewards.append(reward)

    # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
    update_N(N[t])

    L = [calculate_queues_load(N[t], v) for v in V]

    if t < T - 1:
        N[t + 1] = copy.deepcopy(N[t])
    print()

print(f"\nreward = {sum(rewards) / T}\n")
# Out:
# t = 0, thread = [6 3]	reward = 0.9862	route = [6, 4]
# t = 1, thread = [4 6]	reward = 0.9849	route = [4]
# t = 2, thread = [2 4]	reward = 0.9839	route = [2, 7]
# t = 3, thread = [4 6]	reward = 0.9826	route = [4, 5]
# t = 4, thread = [1 2]	reward = 0.9827	route = [1, 0, 5, 4, 3]
# t = 5, thread = [6 2]	reward = 0.9669	route = [6, 5, 4, 7]
# t = 6, thread = [2 4]	reward = 0.9677	route = [2, 7]
# t = 7, thread = [3 2]	reward = 0.9883	route = [3, 4, 1]
# t = 8, thread = [5 4]	reward = 0.9883	route = [5]
# t = 9, thread = [1 3]	reward = 0.9687	route = [1, 4, 7, 2]
# t = 10, thread = [5 0]	reward = 0.9681	route = [5, 6, 4, 1]
# t = 11, thread = [1 3]	reward = 0.9603	route = [1, 2, 7, 4]
# t = 12, thread = [4 0]	reward = 0.9603	route = [4, 1]
# t = 13, thread = [3 1]	reward = 0.9858	route = [3, 2]
# t = 14, thread = [5 4]	reward = 0.9858	route = [5]
# t = 15, thread = [3 0]	reward = 0.9948	route = [3, 4, 6, 5]
# t = 16, thread = [0 2]	reward = 0.9801	route = [0, 5, 6, 4, 7]
# t = 17, thread = [2 6]	reward = 0.9832	route = [2, 3, 4]
# t = 18, thread = [1 3]	reward = 0.9623	route = [1, 2]
# t = 19, thread = [3 6]	reward = 0.9599	route = [3, 4]
# t = 20, thread = [4 5]	reward = 0.9599	route = [4]
# t = 21, thread = [6 5]	reward = 0.9588	route = [6]
# t = 22, thread = [2 3]	reward = 0.9733	route = [2, 7, 4]
# t = 23, thread = [6 3]	reward = 0.9731	route = [6, 4]
# t = 24, thread = [0 2]	reward = 0.978	route = [0, 5, 4, 7]
# t = 25, thread = [4 2]	reward = 0.9729	route = [4, 1]
# t = 26, thread = [6 4]	reward = 0.9681	route = [6, 5]
# t = 27, thread = [0 6]	reward = 0.9735	route = [0, 5, 4]
# t = 28, thread = [1 3]	reward = 0.967	route = [1, 2]
# t = 29, thread = [0 3]	reward = 0.9698	route = [0, 5, 6, 4]
# t = 30, thread = [5 1]	reward = 0.962	route = [5, 6, 4]
# t = 31, thread = [1 0]	reward = 0.9672	route = [1]
# t = 32, thread = [1 4]	reward = 0.9868	route = [1]
# t = 33, thread = [1 3]	reward = 0.9744	route = [1, 2]
# t = 34, thread = [3 6]	reward = 0.9745	route = [3, 4]
# t = 35, thread = [3 6]	reward = 0.9674	route = [3, 2, 7, 4]
# t = 36, thread = [3 4]	reward = 0.9847	route = [3]
# t = 37, thread = [6 2]	reward = 0.9411	route = [6, 4, 3]
# t = 38, thread = [5 0]	reward = 0.9409	route = [5]
# t = 39, thread = [3 1]	reward = 0.9515	route = [3, 4]
# t = 40, thread = [3 1]	reward = 0.9565	route = [3, 2]
# t = 41, thread = [5 0]	reward = 0.9556	route = [5, 4, 7, 2, 1]
# t = 42, thread = [5 1]	reward = 0.9559	route = [5, 0]
# t = 43, thread = [3 5]	reward = 0.9838	route = [3, 4, 6]
# t = 44, thread = [4 6]	reward = 0.9906	route = [4]
# t = 45, thread = [3 4]	reward = 0.9892	route = [3]
# t = 46, thread = [3 1]	reward = 0.9807	route = [3, 2]
# t = 47, thread = [1 5]	reward = 0.9816	route = [1, 4]
# t = 48, thread = [3 5]	reward = 0.9858	route = [3, 4]
# t = 49, thread = [3 5]	reward = 0.9858	route = [3, 4]
# t = 50, thread = [5 6]	reward = 0.9859	route = [5, 4]
# t = 51, thread = [3 0]	reward = 0.9855	route = [3, 4, 1]
# t = 52, thread = [5 4]	reward = 0.9858	route = [5, 6]
# t = 53, thread = [4 1]	reward = 0.9565	route = [4]
# t = 54, thread = [6 4]	reward = 0.9459	route = [6, 5]
# t = 55, thread = [1 0]	reward = 0.9649	route = [1, 4, 5]
# t = 56, thread = [5 2]	reward = 0.9909	route = [5, 6, 4, 7]
# t = 57, thread = [3 4]	reward = 0.9779	route = [3]
# t = 58, thread = [0 4]	reward = 0.988	route = [0, 1, 2, 3]
# t = 59, thread = [6 4]	reward = 0.98	route = [6]
# t = 60, thread = [1 6]	reward = 0.9784	route = [1, 2, 3, 4, 5]
# t = 61, thread = [6 0]	reward = 0.9783	route = [6, 5]
# t = 62, thread = [0 3]	reward = 0.978	route = [0, 5, 4]
# t = 63, thread = [6 2]	reward = 0.9575	route = [6, 4, 1]
# t = 64, thread = [2 0]	reward = 0.965	route = [2, 3, 4, 6, 5]
# t = 65, thread = [3 0]	reward = 0.9566	route = [3, 4, 5]
# t = 66, thread = [0 2]	reward = 0.9707	route = [0, 5, 4, 7]
# t = 67, thread = [4 1]	reward = 0.9673	route = [4, 3, 2]
# t = 68, thread = [6 1]	reward = 0.9636	route = [6, 4, 7, 2]
# t = 69, thread = [0 3]	reward = 0.9648	route = [0, 1, 2]
# t = 70, thread = [6 0]	reward = 0.9678	route = [6, 5]
# t = 71, thread = [3 1]	reward = 0.981	route = [3, 2, 7, 4]
# t = 72, thread = [0 6]	reward = 0.9807	route = [0, 5, 4]
# t = 73, thread = [6 5]	reward = 0.9842	route = [6]
# t = 74, thread = [4 2]	reward = 0.9732	route = [4, 7]
# t = 75, thread = [3 5]	reward = 0.9761	route = [3, 4]
# t = 76, thread = [6 5]	reward = 0.9732	route = [6]
# t = 77, thread = [0 2]	reward = 0.9721	route = [0, 1]
# t = 78, thread = [4 6]	reward = 0.9848	route = [4, 5]
# t = 79, thread = [5 2]	reward = 0.9886	route = [5, 6, 4, 1]
# t = 80, thread = [0 4]	reward = 0.9896	route = [0, 1]
# t = 81, thread = [1 6]	reward = 0.9985	route = [1, 4, 5]
# t = 82, thread = [6 5]	reward = 0.9861	route = [6]
# t = 83, thread = [6 2]	reward = 0.9188	route = [6, 5, 4, 3]
# t = 84, thread = [0 6]	reward = 0.9189	route = [0, 5]
# t = 85, thread = [6 1]	reward = 0.9189	route = [6, 4, 7, 2]
# t = 86, thread = [1 3]	reward = 0.9733	route = [1, 2]
# t = 87, thread = [4 2]	reward = 0.9681	route = [4, 3]
# t = 88, thread = [0 2]	reward = 0.9643	route = [0, 5, 6, 4, 7]
# t = 89, thread = [0 3]	reward = 0.9691	route = [0, 1, 4]
# t = 90, thread = [4 3]	reward = 0.9526	route = [4]
# t = 91, thread = [5 4]	reward = 0.989	route = [5]
# t = 92, thread = [0 2]	reward = 0.9763	route = [0, 5, 4, 7]
# t = 93, thread = [4 6]	reward = 0.9759	route = [4, 5]
# t = 94, thread = [2 4]	reward = 0.9762	route = [2, 7]
# t = 95, thread = [3 4]	reward = 0.9764	route = [3]
# t = 96, thread = [6 2]	reward = 0.9702	route = [6, 5, 0, 1]
# t = 97, thread = [2 5]	reward = 0.9684	route = [2, 7, 4, 1, 0]
# t = 98, thread = [3 1]	reward = 0.9836	route = [3, 2]
# t = 99, thread = [1 4]	reward = 0.9823	route = [1]
#
# reward = 0.9723124580959167

# %% [markdown]
# #Анализ

# %%
# Анализ маршрутов и наград в фиксированный момент времени t (Необходима сформированный список N[t])
t = 88
v_src, v_dst = Times_test[t][0:2]

print(f't = {t}. Поток = ({v_src} -> {v_dst}), dt = {dt}, L = {round(λ[v_src, v_dst] / μ, 3)}')

rewards_t = []
for path in paths[v_src][v_dst]:
    N_t = copy.deepcopy(N[t - 1]) # N до прихода t-го потока

    for k in range(len(path) - 1):
        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        v = path[k]
        action = E_v[v].index(path[k + 1])
        add_thread_N(N_t[v], v_src, v_dst, action, dt)

    L = [calculate_queues_load(N_t, v) for v in V]

    # Расчет наград
    reward = get_reward(L)
    rewards_t.append(reward)
    print(f"route = {str(path):25}", end='\t')
    print(f"reward = {round(reward, 4)}")

print(f"Полученный reward = {round(rewards[t], 4)};")
print(f"Недополученный reward = {round(max(rewards_t) - rewards[t], 4)}\n")

visualize(G, N_t, Times_test[t][:2])
# Out:
# t = 88. Поток = (0 -> 2), dt = 4, L = 0.365
# route = [0, 1, 2]                	reward = 0.9307
# route = [0, 1, 4, 3, 2]          	reward = 0.909
# route = [0, 1, 4, 7, 2]          	reward = 0.9651
# route = [0, 5, 4, 1, 2]          	reward = 0.9312
# route = [0, 5, 4, 3, 2]          	reward = 0.909
# route = [0, 5, 4, 7, 2]          	reward = 0.9651
# route = [0, 5, 6, 4, 1, 2]       	reward = 0.9311
# route = [0, 5, 6, 4, 3, 2]       	reward = 0.9092
# route = [0, 5, 6, 4, 7, 2]       	reward = 0.9643
# Полученный reward = 0.9643;
# Недополученный reward = 0.0008
#
# Текущие потоки в сети:
# Поток = (0 -> 2), L = 0.041
# Поток = (1 -> 3), L = 0.083
# Поток = (4 -> 2), L = 0.083
# Поток = (6 -> 1), L = 0.002
#
# Выделенный поток = (0 -> 2), L = 0.041
# L_mean = 0.0286, reward = 0.9643

# %%
# Недополученные награды на каждом шаге t
# Выводит разность между максимально возможной и реально полученной наградой на каждом шаге t
print('t\tmax-min\tmax-current')

lost_rewards = []     # (max - current) - недополученная награда на каждом шаге
for t in range(1, T):
    v_src, v_dst = Times_test[t][0:2]

    rewards_t = []
    for path in paths[v_src][v_dst]:
        N_t = copy.deepcopy(N[t - 1]) # N до прихода t-го потока

        for k in range(len(path) - 1):
            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            v = path[k]
            action = E_v[v].index(path[k + 1])
            add_thread_N(N_t[v], v_src, v_dst, action, dt)

        L = [calculate_queues_load(N_t, v) for v in V]

        rewards_t.append(get_reward(L))

    lost_rewards.append(max(rewards_t) - rewards[t])
    print(f"{str(t)}\t{round(max(rewards_t) - min(rewards_t), 4)}\t{round(max(rewards_t) - rewards[t], 4)}")
# Out:
# t	max-min	max-current
# 1	0.033	0.0
# 2	0.0269	0.0
# 3	0.0301	0.0
# 4	0.0008	0.0003
# 5	0.0648	0.0004
# 6	0.0282	0.0
# 7	0.0044	0.0001
# 8	0.0079	0.0001
# 9	0.0553	0.0059
# 10	0.006	0.0001
# 11	0.117	0.0
# 12	0.0022	0.0
# 13	0.0093	0.0
# 14	0.0002	0.0002
# 15	0.0048	0.0005
# 16	0.0123	0.0079
# 17	0.0119	0.0
# 18	0.1051	0.0113
# 19	0.004	0.004
# 20	0.0015	0.0
# 21	0.002	0.0
# 22	0.012	0.0003
# 23	0.0474	0.0052
# 24	0.0487	0.0009
# 25	0.0625	0.0
# 26	0.0523	0.0
# 27	0.0017	0.0017
# 28	0.0759	0.0
# 29	0.0597	0.0
# 30	0.0186	0.0142
# 31	0.0009	0.0009
# 32	0.0534	0.0
# 33	0.0578	0.0
# 34	0.0274	0.0004
# 35	0.0378	0.0168
# 36	0.0362	0.0
# 37	0.0608	0.0301
# 38	0.0113	0.0001
# 39	0.0245	0.0
# 40	0.0702	0.0
# 41	0.0019	0.0009
# 42	0.0217	0.0
# 43	0.0022	0.0011
# 44	0.0109	0.0
# 45	0.0045	0.0
# 46	0.0593	0.0
# 47	0.0032	0.0001
# 48	0.0024	0.0
# 49	0.0024	0.0
# 50	0.0004	0.0002
# 51	0.0307	0.0
# 52	0.0021	0.0002
# 53	0.0171	0.0171
# 54	0.0127	0.0047
# 55	0.0279	0.0003
# 56	0.0006	0.0
# 57	0.0183	0.0111
# 58	0.0026	0.0024
# 59	0.0656	0.0
# 60	0.0038	0.0038
# 61	0.0296	0.0002
# 62	0.0344	0.0
# 63	0.0589	0.0127
# 64	0.0096	0.0016
# 65	0.0238	0.0143
# 66	0.077	0.0
# 67	0.0542	0.0
# 68	0.0144	0.0079
# 69	0.0484	0.0
# 70	0.0581	0.0005
# 71	0.049	0.0032
# 72	0.0023	0.0
# 73	0.0141	0.0
# 74	0.0554	0.0
# 75	0.0032	0.0
# 76	0.0809	0.0
# 77	0.0628	0.0
# 78	0.0041	0.0019
# 79	0.0005	0.0005
# 80	0.0043	0.0
# 81	0.0008	0.0008
# 82	0.016	0.0
# 83	0.0525	0.0499
# 84	0.0005	0.0
# 85	0.0174	0.0
# 86	0.0224	0.0
# 87	0.0557	0.0
# 88	0.0561	0.0008
# 89	0.0714	0.0
# 90	0.0543	0.0
# 91	0.0001	0.0001
# 92	0.0404	0.0082
# 93	0.0472	0.0002
# 94	0.0432	0.0
# 95	0.0411	0.0007
# 96	0.0769	0.0015
# 97	0.0032	0.0005
# 98	0.0352	0.0
# 99	0.0112	0.0

# %%
lost_rewards_percent = np.cumsum(lost_rewards) / T / (max_reward - min_reward)

plt.title('Недополученная масштабированная награда')
plt.xlabel('t')
plt.ylabel('max_r(t) - r(t)')
plt.grid()
plt.ylim([0, 0.05])
plt.plot(np.arange(T - 1), lost_rewards_percent)
plt.show()

# %%
# Максимальный reward (субоптимальный), если выбирать оптимальные действия на каждом шаге (с подробным выводом)
max_reward = get_max_min_optimal_reward(Times_test, 'argmax', verbose=True) / T
print(f"\nmax reward = {max_reward}")
# Out:
# t = 0	 reward = 0.986	 route = [6, 4, 3]
# t = 1	 reward = 0.985	 route = [4, 6]
# t = 2	 reward = 0.984	 route = [2, 1, 4]
# t = 3	 reward = 0.983	 route = [4, 5, 6]
# t = 4	 reward = 0.983	 route = [1, 0, 5, 4, 7, 2]
# t = 5	 reward = 0.967	 route = [6, 5, 0, 1, 2]
# t = 6	 reward = 0.969	 route = [2, 1, 0, 5, 4]
# t = 7	 reward = 0.987	 route = [3, 4, 6, 5, 0, 1, 2]
# t = 8	 reward = 0.987	 route = [5, 0, 1, 2, 7, 4]
# t = 9	 reward = 0.976	 route = [1, 4, 3]
# t = 10	 reward = 0.976	 route = [5, 6, 4, 7, 2, 1, 0]
# t = 11	 reward = 0.96	 route = [1, 2, 3]
# t = 12	 reward = 0.96	 route = [4, 7, 2, 1, 0]
# t = 13	 reward = 0.986	 route = [3, 4, 1]
# t = 14	 reward = 0.986	 route = [5, 0, 1, 2, 7, 4]
# t = 15	 reward = 0.993	 route = [3, 4, 1, 0]
# t = 16	 reward = 0.985	 route = [0, 5, 4, 3, 2]
# t = 17	 reward = 0.985	 route = [2, 1, 4, 5, 6]
# t = 18	 reward = 0.964	 route = [1, 2, 3]
# t = 19	 reward = 0.965	 route = [3, 4, 6]
# t = 20	 reward = 0.965	 route = [4, 3, 2, 1, 0, 5]
# t = 21	 reward = 0.974	 route = [6, 5]
# t = 22	 reward = 0.974	 route = [2, 1, 0, 5, 6, 4, 3]
# t = 23	 reward = 0.972	 route = [6, 4, 1, 2, 3]
# t = 24	 reward = 0.977	 route = [0, 1, 4, 3, 2]
# t = 25	 reward = 0.973	 route = [4, 7, 2]
# t = 26	 reward = 0.968	 route = [6, 5, 4]
# t = 27	 reward = 0.973	 route = [0, 1, 4, 5, 6]
# t = 28	 reward = 0.966	 route = [1, 4, 3]
# t = 29	 reward = 0.97	 route = [0, 5, 6, 4, 1, 2, 3]
# t = 30	 reward = 0.977	 route = [5, 4, 7, 2, 1]
# t = 31	 reward = 0.989	 route = [1, 4, 6, 5, 0]
# t = 32	 reward = 0.981	 route = [1, 2, 3, 4]
# t = 33	 reward = 0.968	 route = [1, 0, 5, 6, 4, 3]
# t = 34	 reward = 0.964	 route = [3, 2, 7, 4, 6]
# t = 35	 reward = 0.959	 route = [3, 2, 1, 0, 5, 6]
# t = 36	 reward = 0.969	 route = [3, 2, 7, 4]
# t = 37	 reward = 0.965	 route = [6, 4, 7, 2]
# t = 38	 reward = 0.962	 route = [5, 0]
# t = 39	 reward = 0.97	 route = [3, 4, 1]
# t = 40	 reward = 0.957	 route = [3, 2, 1]
# t = 41	 reward = 0.957	 route = [5, 0]
# t = 42	 reward = 0.957	 route = [5, 0, 1]
# t = 43	 reward = 0.984	 route = [3, 2, 1, 4, 6, 5]
# t = 44	 reward = 0.99	 route = [4, 6]
# t = 45	 reward = 0.989	 route = [3, 4]
# t = 46	 reward = 0.981	 route = [3, 2, 1]
# t = 47	 reward = 0.985	 route = [1, 2, 3, 4, 5]
# t = 48	 reward = 0.986	 route = [3, 4, 5]
# t = 49	 reward = 0.986	 route = [3, 4, 1, 0, 5]
# t = 50	 reward = 0.986	 route = [5, 0, 1, 4, 6]
# t = 51	 reward = 0.984	 route = [3, 4, 1, 0]
# t = 52	 reward = 0.985	 route = [5, 6, 4]
# t = 53	 reward = 0.974	 route = [4, 3, 2, 1]
# t = 54	 reward = 0.969	 route = [6, 5, 4]
# t = 55	 reward = 0.976	 route = [1, 2, 7, 4, 5, 0]
# t = 56	 reward = 0.984	 route = [5, 6, 4, 3, 2]
# t = 57	 reward = 0.988	 route = [3, 2, 1, 4]
# t = 58	 reward = 0.988	 route = [0, 5, 6, 4]
# t = 59	 reward = 0.978	 route = [6, 5, 4]
# t = 60	 reward = 0.978	 route = [1, 2, 3, 4, 5, 6]
# t = 61	 reward = 0.977	 route = [6, 4, 1, 0]
# t = 62	 reward = 0.978	 route = [0, 1, 2, 7, 4, 3]
# t = 63	 reward = 0.972	 route = [6, 5, 4, 7, 2]
# t = 64	 reward = 0.971	 route = [2, 3, 4, 5, 0]
# t = 65	 reward = 0.972	 route = [3, 2, 1, 4, 5, 0]
# t = 66	 reward = 0.97	 route = [0, 5, 6, 4, 1, 2]
# t = 67	 reward = 0.942	 route = [4, 3, 2, 1]
# t = 68	 reward = 0.971	 route = [6, 5, 0, 1]
# t = 69	 reward = 0.973	 route = [0, 1, 4, 7, 2, 3]
# t = 70	 reward = 0.973	 route = [6, 5, 4, 1, 0]
# t = 71	 reward = 0.982	 route = [3, 2, 1]
# t = 72	 reward = 0.982	 route = [0, 5, 4, 6]
# t = 73	 reward = 0.984	 route = [6, 5]
# t = 74	 reward = 0.973	 route = [4, 1, 2]
# t = 75	 reward = 0.976	 route = [3, 4, 7, 2, 1, 0, 5]
# t = 76	 reward = 0.973	 route = [6, 5]
# t = 77	 reward = 0.972	 route = [0, 1, 4, 3, 2]
# t = 78	 reward = 0.983	 route = [4, 6]
# t = 79	 reward = 0.993	 route = [5, 0, 1, 4, 7, 2]
# t = 80	 reward = 0.993	 route = [0, 1, 2, 3, 4]
# t = 81	 reward = 0.999	 route = [1, 0, 5, 6]
# t = 82	 reward = 0.986	 route = [6, 5]
# t = 83	 reward = 0.969	 route = [6, 4, 1, 2]
# t = 84	 reward = 0.97	 route = [0, 5, 6]
# t = 85	 reward = 0.966	 route = [6, 5, 4, 7, 2, 1]
# t = 86	 reward = 0.969	 route = [1, 2, 3]
# t = 87	 reward = 0.968	 route = [4, 3, 2]
# t = 88	 reward = 0.965	 route = [0, 5, 6, 4, 7, 2]
# t = 89	 reward = 0.971	 route = [0, 1, 4, 3]
# t = 90	 reward = 0.953	 route = [4, 3]
# t = 91	 reward = 0.989	 route = [5, 0, 1, 2, 3, 4]
# t = 92	 reward = 0.982	 route = [0, 5, 4, 7, 2]
# t = 93	 reward = 0.982	 route = [4, 6]
# t = 94	 reward = 0.982	 route = [2, 1, 4]
# t = 95	 reward = 0.982	 route = [3, 2, 7, 4]
# t = 96	 reward = 0.972	 route = [6, 4, 1, 2]
# t = 97	 reward = 0.971	 route = [2, 3, 4, 5]
# t = 98	 reward = 0.985	 route = [3, 2, 1]
# t = 99	 reward = 0.982	 route = [1, 4]
#
# max reward = 0.9759624377243478

# %%
# Минимальный reward (субоптимальный), если выбирать оптимальные действия на каждом шаге (с подробным выводом)
min_reward = get_max_min_optimal_reward(Times_test, 'argmin', verbose=True) / T
print(f"\nmin reward = {min_reward}")
# Out:
# t = 0	 reward = 0.978	 route = [6, 5, 0, 1, 2, 7, 4, 3]
# t = 1	 reward = 0.952	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 2	 reward = 0.929	 route = [2, 1, 0, 5, 6, 4]
# t = 3	 reward = 0.827	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 4	 reward = 0.883	 route = [1, 0, 5, 6, 4, 3, 2]
# t = 5	 reward = 0.842	 route = [6, 5, 0, 1, 4, 3, 2]
# t = 6	 reward = 0.839	 route = [2, 1, 4]
# t = 7	 reward = 0.962	 route = [3, 2]
# t = 8	 reward = 0.96	 route = [5, 6, 4]
# t = 9	 reward = 0.871	 route = [1, 0, 5, 6, 4, 3]
# t = 10	 reward = 0.939	 route = [5, 6, 4, 3, 2, 1, 0]
# t = 11	 reward = 0.8	 route = [1, 0, 5, 6, 4, 3]
# t = 12	 reward = 0.796	 route = [4, 3, 2, 1, 0]
# t = 13	 reward = 0.974	 route = [3, 2, 7, 4, 6, 5, 0, 1]
# t = 14	 reward = 0.959	 route = [5, 0, 1, 2, 7, 4]
# t = 15	 reward = 0.986	 route = [3, 2, 7, 4, 5, 0]
# t = 16	 reward = 0.954	 route = [0, 1, 4, 3, 2]
# t = 17	 reward = 0.973	 route = [2, 1, 4, 6]
# t = 18	 reward = 0.893	 route = [1, 4, 3]
# t = 19	 reward = 0.919	 route = [3, 2, 1, 4, 6]
# t = 20	 reward = 0.918	 route = [4, 3, 2, 1, 0, 5]
# t = 21	 reward = 0.861	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 22	 reward = 0.848	 route = [2, 1, 4, 3]
# t = 23	 reward = 0.873	 route = [6, 4, 3]
# t = 24	 reward = 0.811	 route = [0, 5, 6, 4, 3, 2]
# t = 25	 reward = 0.838	 route = [4, 3, 2]
# t = 26	 reward = 0.905	 route = [6, 4]
# t = 27	 reward = 0.932	 route = [0, 5, 6]
# t = 28	 reward = 0.854	 route = [1, 0, 5, 6, 4, 3]
# t = 29	 reward = 0.854	 route = [0, 5, 6, 4, 3]
# t = 30	 reward = 0.841	 route = [5, 6, 4, 3, 2, 1]
# t = 31	 reward = 0.961	 route = [1, 0]
# t = 32	 reward = 0.934	 route = [1, 0, 5, 6, 4]
# t = 33	 reward = 0.807	 route = [1, 0, 5, 6, 4, 3]
# t = 34	 reward = 0.763	 route = [3, 4, 1, 0, 5, 6]
# t = 35	 reward = 0.825	 route = [3, 4, 1, 0, 5, 6]
# t = 36	 reward = 0.826	 route = [3, 2, 1, 0, 5, 6, 4]
# t = 37	 reward = 0.8	 route = [6, 4, 1, 2]
# t = 38	 reward = 0.901	 route = [5, 6, 4, 1, 0]
# t = 39	 reward = 0.897	 route = [3, 2, 7, 4, 1]
# t = 40	 reward = 0.867	 route = [3, 2, 7, 4, 1]
# t = 41	 reward = 0.862	 route = [5, 4, 3, 2, 1, 0]
# t = 42	 reward = 0.842	 route = [5, 6, 4, 3, 2, 1]
# t = 43	 reward = 0.95	 route = [3, 2, 7, 4, 1, 0, 5]
# t = 44	 reward = 0.936	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 45	 reward = 0.864	 route = [3, 2, 1, 0, 5, 6, 4]
# t = 46	 reward = 0.809	 route = [3, 2, 1]
# t = 47	 reward = 0.92	 route = [1, 0, 5]
# t = 48	 reward = 0.983	 route = [3, 2, 1, 4, 5]
# t = 49	 reward = 0.981	 route = [3, 2, 1, 4, 6, 5]
# t = 50	 reward = 0.981	 route = [5, 6]
# t = 51	 reward = 0.946	 route = [3, 2, 1, 0]
# t = 52	 reward = 0.95	 route = [5, 4]
# t = 53	 reward = 0.939	 route = [4, 3, 2, 1]
# t = 54	 reward = 0.934	 route = [6, 5, 4]
# t = 55	 reward = 0.941	 route = [1, 4, 6, 5, 0]
# t = 56	 reward = 0.989	 route = [5, 0, 1, 4, 3, 2]
# t = 57	 reward = 0.959	 route = [3, 2, 1, 4]
# t = 58	 reward = 0.958	 route = [0, 1, 4]
# t = 59	 reward = 0.871	 route = [6, 5, 0, 1, 4]
# t = 60	 reward = 0.918	 route = [1, 4, 6]
# t = 61	 reward = 0.899	 route = [6, 5, 0]
# t = 62	 reward = 0.856	 route = [0, 1, 4, 3]
# t = 63	 reward = 0.843	 route = [6, 5, 0, 1, 4, 3, 2]
# t = 64	 reward = 0.855	 route = [2, 1, 4, 6, 5, 0]
# t = 65	 reward = 0.814	 route = [3, 2, 1, 4, 6, 5, 0]
# t = 66	 reward = 0.82	 route = [0, 1, 4, 3, 2]
# t = 67	 reward = 0.752	 route = [4, 6, 5, 0, 1]
# t = 68	 reward = 0.917	 route = [6, 5, 0, 1]
# t = 69	 reward = 0.873	 route = [0, 1, 4, 3]
# t = 70	 reward = 0.893	 route = [6, 5, 0]
# t = 71	 reward = 0.914	 route = [3, 4, 6, 5, 0, 1]
# t = 72	 reward = 0.937	 route = [0, 1, 2, 3, 4, 6]
# t = 73	 reward = 0.947	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 74	 reward = 0.892	 route = [4, 3, 2]
# t = 75	 reward = 0.974	 route = [3, 2, 1, 0, 5]
# t = 76	 reward = 0.889	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 77	 reward = 0.814	 route = [0, 5, 6, 4, 3, 2]
# t = 78	 reward = 0.917	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 79	 reward = 0.982	 route = [5, 6, 4, 3, 2]
# t = 80	 reward = 0.979	 route = [0, 5, 6, 4]
# t = 81	 reward = 0.998	 route = [1, 0, 5, 6]
# t = 82	 reward = 0.955	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 83	 reward = 0.868	 route = [6, 4, 3, 2]
# t = 84	 reward = 0.868	 route = [0, 5, 4, 6]
# t = 85	 reward = 0.846	 route = [6, 4, 3, 2, 1]
# t = 86	 reward = 0.844	 route = [1, 0, 5, 6, 4, 3]
# t = 87	 reward = 0.897	 route = [4, 3, 2]
# t = 88	 reward = 0.817	 route = [0, 5, 6, 4, 3, 2]
# t = 89	 reward = 0.788	 route = [0, 5, 6, 4, 3]
# t = 90	 reward = 0.778	 route = [4, 3]
# t = 91	 reward = 0.989	 route = [5, 4]
# t = 92	 reward = 0.944	 route = [0, 5, 4, 3, 2]
# t = 93	 reward = 0.884	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 94	 reward = 0.853	 route = [2, 1, 0, 5, 4]
# t = 95	 reward = 0.788	 route = [3, 2, 1, 0, 5, 4]
# t = 96	 reward = 0.735	 route = [6, 5, 4, 3, 2]
# t = 97	 reward = 0.797	 route = [2, 1, 0, 5]
# t = 98	 reward = 0.926	 route = [3, 2, 1]
# t = 99	 reward = 0.969	 route = [1, 0, 5, 6, 4]
#
# min reward = 0.8919704050626504

# %%
# Пример использования визуализации
visualize(G, N[5], [4, 6])
# Out:
# Текущие потоки в сети:
# Поток = (1 -> 2), L = 0.0
# Поток = (4 -> 6), L = 0.034
# Поток = (6 -> 2), L = 0.083
# Поток = (6 -> 3), L = 0.048
#
# Выделенный поток = (4 -> 6), L = 0.034
# L_mean = 0.023, reward = 0.9669

# %% [markdown]
# **График $L(\rho,S)$**

# %%
s = 5
ρ = np.linspace(0, 5, 100)

L = loading_queue(ρ, s) / s

# %%
plt.plot(ρ, L)

plt.xlabel('ρ')
plt.ylabel('L(ρ, S) / S')

plt.xlim(0, s)
plt.ylim(0, 1)

plt.grid()
plt.show()

# %% [markdown]
# # Сравнение

# %%
with open('/content/drive/MyDrive/marl/2/Easy.pickle', 'rb') as f:
   easy_rewards, easy_losses = pickle.load(f)

with open('/content/drive/MyDrive/marl/3/Hard.pickle', 'rb') as f:
   hard_rewards, hard_losses = pickle.load(f)

# %%
x = range(0, total_steps, eval_freq)

plt.figure(figsize=(12, 8))
plt.title('График зависимости масштабированной награды от времени')
plt.xlabel('t')
plt.ylabel('r(t)')
plt.grid()
plt.ylim([0, 1])

plt.plot(x, hard_rewards, label='Без централизованного знания сети')
plt.plot(x, easy_rewards, label='С централизованным знанием сети')
plt.legend()

plt.show()

# %%
with open(f'{PATH}lost_rewards.pickle', 'wb') as f:
   pickle.dump(lost_rewards_percent, f)

# %% [markdown]
# # Проверка гипотезы

# %%
# Загрузка сохраненных моделей и параметров оптимизаторов
PATH = '/content/drive/MyDrive/marl/2/'

for v in V:
    agents[v].load_state_dict(torch.load(PATH + f'model_{v}'))
    optimizers[v].load_state_dict(torch.load(PATH + f'opt_{v}'))

# %%
seed_rewards = []

for seed in range(225):

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    T = 100
    Times_test = generate_treads(T)

    # Создает массив N(t), сохраняющий поступающие потоки в каждый момент времени t, для анализа
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [[{'n': np.zeros((0, 2), dtype=np.int32),
          'q': np.zeros(0, dtype=np.int32),
          't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))] for _ in range(T)]

    transitions = [[] for _ in V]
    rewards = []

    for t in range(T):
        v_src, v_dst, dt = Times_test[t]

        route = []
        v = v_src
        while v != v_dst:
            route.append(v)

            # Формирование состояния для подачи на вход нейронке:
            # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
            OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[t][v]['n']], axis=0)
            state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])

            # Выбор действия жадно
            E_valid = find_next_vertices(paths[v_src][v_dst], route)
            action = agents[v].get_action(state, E_v[v], E_valid)

            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            add_thread_N(N[t][v], v_src, v_dst, action, dt)

            # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
            L[v] = calculate_queues_load(N[t], v)

            v = E_v[v][action]

        # Расчет награды и возвращение ее в переходы всем агентам
        reward = get_reward(L)
        rewards.append(reward)

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N[t])

        L = [calculate_queues_load(N[t], v) for v in V]

        if t < T - 1:
            N[t + 1] = copy.deepcopy(N[t])

    seed_rewards.append(sum(rewards) / T)

np.array(seed_rewards)
# Out:
# array([0.96844659, 0.96971634, 0.9692314 , 0.96208902, 0.97613968,
#        0.96985615, 0.97216398, 0.97530123, 0.96875303, 0.96460234,
#        0.96838136, 0.97066421, 0.9637101 , 0.96934336, 0.97476479,
#        0.96748212, 0.96346753, 0.9663951 , 0.96657713, 0.96592835,
#        0.97565514, 0.96826623, 0.97295095, 0.97318276, 0.97560057,
#        0.97371144, 0.97096534, 0.97055173, 0.96868246, 0.96552508,
#        0.9714789 , 0.9676375 , 0.97543968, 0.96403077, 0.97451575,
#        0.97028981, 0.97425367, 0.97138899, 0.96774053, 0.96044729,
#        0.96767786, 0.97803649, 0.97231246, 0.97159807, 0.97270869,
#        0.97214726, 0.97136762, 0.95964054, 0.97115448, 0.96574887,
#        0.96920308, 0.97009654, 0.96901379, 0.97233685, 0.97222113,
#        0.97514194, 0.96799715, 0.96868466, 0.96789187, 0.97515914,
#        0.96372225, 0.97502849, 0.96947287, 0.97319627, 0.976709  ,
#        0.97384326, 0.97036774, 0.96775263, 0.96908897, 0.97752086,
#        0.96967656, 0.97276886, 0.97608848, 0.97317661, 0.97082624,
#        0.97600333, 0.96976605, 0.96775576, 0.97379085, 0.97190842,
#        0.97064896, 0.97572008, 0.9697396 , 0.96823675, 0.96302836,
#        0.97093198, 0.97392264, 0.9686213 , 0.9635865 , 0.97179539,
#        0.972756  , 0.97369203, 0.96333745, 0.97304368, 0.9744469 ,
#        0.96509061, 0.97272992, 0.97389201, 0.97197056, 0.97219273,
#        0.96955238, 0.96988797, 0.96675194, 0.96600226, 0.96697157,
#        0.97267854, 0.96583824, 0.97271403, 0.96828717, 0.97301395,
#        0.97315859, 0.96930231, 0.97210319, 0.97630035, 0.95527495,
#        0.97132358, 0.95567584, 0.97019062, 0.96692718, 0.97246312,
#        0.96959387, 0.97285895, 0.96603099, 0.96789225, 0.96952699,
#        0.96852961, 0.97047821, 0.96511669, 0.96900506, 0.96539537,
#        0.9689677 , 0.97302105, 0.97380837, 0.96319533, 0.97125333,
#        0.97049287, 0.97562657, 0.97324584, 0.97034569, 0.97609567,
#        0.9694588 , 0.96417965, 0.9652993 , 0.96907655, 0.96874972,
#        0.97391482, 0.97275488, 0.97361478, 0.96469496, 0.97313578,
#        0.97384498, 0.96915458, 0.96995104, 0.97488189, 0.96737515,
#        0.96850584, 0.9682052 , 0.97261819, 0.97745507, 0.97042261,
#        0.95984526, 0.96636261, 0.97544319, 0.97161641, 0.97864013,
#        0.9734558 , 0.97408897, 0.96980087, 0.96482573, 0.96937397,
#        0.96970587, 0.97148329, 0.97070806, 0.97164844, 0.97151724,
#        0.97652626, 0.97529691, 0.9761472 , 0.97194948, 0.96848333,
#        0.96484931, 0.96858162, 0.97377078, 0.96986783, 0.96361826,
#        0.96895805, 0.96933308, 0.97226706, 0.97701128, 0.98026374,
#        0.97237003, 0.96694529, 0.97229335, 0.97258953, 0.97419635,
#        0.97153794, 0.97327628, 0.96191465, 0.97715887, 0.97020714,
#        0.97687688, 0.96437385, 0.97399502, 0.9746909 , 0.9643572 ,
#        0.9742032 , 0.97221067, 0.96665501, 0.96720673, 0.974001  ,
#        0.97076651, 0.96656796, 0.97594274, 0.96935048, 0.96865645,
#        0.9713133 , 0.96697994, 0.9738366 , 0.96815246, 0.96932991,
#        0.97400859, 0.97329312, 0.97979129, 0.96456393, 0.97447846])

# %%
seed_rewards = np.array(seed_rewards)

np.mean(seed_rewards > 0.96)
# Out:
# 0.9822222222222222

# %% [markdown]
# # Сравнение с ECMP

# %%
# Создает массив N(t), сохраняющий поступающие потоки в каждый момент времени t, для анализа

L = [np.zeros(len(E_v[v])) for v in range(len(V))]
N = [[{'n': np.zeros((0, 2), dtype=np.int32),
       'q': np.zeros(0, dtype=np.int32),
       't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))] for _ in range(T)]

transitions = [[] for _ in V]
rewards = []

for t in range(T):
    print(f"t = {t}, thread = {Times_test[t][0:2]}", end='\t')
    v_src, v_dst, dt = Times_test[t]

    route = []

    shortest_len = min(len(path) for path in paths[v_src][v_dst])
    shortest_paths = [path for path in paths[v_src][v_dst] if len(path) == shortest_len]
    route = random.choice(shortest_paths)

    for v, action in zip(route, route[1:]):
        add_thread_N(N[t][v], v_src, v_dst, E_v[v].index(action), dt)

    L = [calculate_queues_load(N[t], v) for v in V]

    # Расчет награды и возвращение ее в переходы всем агентам
    reward = get_reward(L)
    print(f"reward = {round(reward, 4)}", end='\t')
    print(f"route = {route}", end='\t')
    rewards.append(reward)

    # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
    update_N(N[t])

    L = [calculate_queues_load(N[t], v) for v in V]

    if t < T - 1:
        N[t + 1] = copy.deepcopy(N[t])
    print()

print(f"\nreward = {sum(rewards) / T}\n")
# Out:
# t = 0, thread = [6 3]	reward = 0.9862	route = [6, 4, 3]
# t = 1, thread = [4 6]	reward = 0.9849	route = [4, 6]
# t = 2, thread = [2 4]	reward = 0.9839	route = [2, 1, 4]
# t = 3, thread = [4 6]	reward = 0.9585	route = [4, 6]
# t = 4, thread = [1 2]	reward = 0.9585	route = [1, 2]
# t = 5, thread = [6 2]	reward = 0.9034	route = [6, 4, 3, 2]
# t = 6, thread = [2 4]	reward = 0.904	route = [2, 1, 4]
# t = 7, thread = [3 2]	reward = 0.99	route = [3, 2]
# t = 8, thread = [5 4]	reward = 0.99	route = [5, 4]
# t = 9, thread = [1 3]	reward = 0.9748	route = [1, 2, 3]
# t = 10, thread = [5 0]	reward = 0.9762	route = [5, 0]
# t = 11, thread = [1 3]	reward = 0.968	route = [1, 4, 3]
# t = 12, thread = [4 0]	reward = 0.968	route = [4, 1, 0]
# t = 13, thread = [3 1]	reward = 0.9857	route = [3, 2, 1]
# t = 14, thread = [5 4]	reward = 0.9858	route = [5, 4]
# t = 15, thread = [3 0]	reward = 0.9946	route = [3, 2, 1, 0]
# t = 16, thread = [0 2]	reward = 0.9878	route = [0, 1, 2]
# t = 17, thread = [2 6]	reward = 0.9884	route = [2, 1, 4, 6]
# t = 18, thread = [1 3]	reward = 0.9626	route = [1, 4, 3]
# t = 19, thread = [3 6]	reward = 0.9615	route = [3, 4, 6]
# t = 20, thread = [4 5]	reward = 0.9615	route = [4, 5]
# t = 21, thread = [6 5]	reward = 0.9602	route = [6, 5]
# t = 22, thread = [2 3]	reward = 0.9732	route = [2, 3]
# t = 23, thread = [6 3]	reward = 0.9806	route = [6, 4, 3]
# t = 24, thread = [0 2]	reward = 0.9789	route = [0, 1, 2]
# t = 25, thread = [4 2]	reward = 0.9292	route = [4, 3, 2]
# t = 26, thread = [6 4]	reward = 0.9047	route = [6, 4]
# t = 27, thread = [0 6]	reward = 0.9321	route = [0, 5, 6]
# t = 28, thread = [1 3]	reward = 0.9047	route = [1, 4, 3]
# t = 29, thread = [0 3]	reward = 0.9227	route = [0, 1, 4, 3]
# t = 30, thread = [5 1]	reward = 0.9235	route = [5, 4, 1]
# t = 31, thread = [1 0]	reward = 0.9898	route = [1, 0]
# t = 32, thread = [1 4]	reward = 0.9869	route = [1, 4]
# t = 33, thread = [1 3]	reward = 0.9743	route = [1, 2, 3]
# t = 34, thread = [3 6]	reward = 0.9743	route = [3, 4, 6]
# t = 35, thread = [3 6]	reward = 0.9568	route = [3, 4, 6]
# t = 36, thread = [3 4]	reward = 0.9685	route = [3, 4]
# t = 37, thread = [6 2]	reward = 0.9607	route = [6, 4, 1, 2]
# t = 38, thread = [5 0]	reward = 0.9609	route = [5, 0]
# t = 39, thread = [3 1]	reward = 0.9184	route = [3, 4, 1]
# t = 40, thread = [3 1]	reward = 0.9565	route = [3, 2, 1]
# t = 41, thread = [5 0]	reward = 0.9565	route = [5, 0]
# t = 42, thread = [5 1]	reward = 0.9465	route = [5, 4, 1]
# t = 43, thread = [3 5]	reward = 0.9633	route = [3, 4, 5]
# t = 44, thread = [4 6]	reward = 0.9917	route = [4, 6]
# t = 45, thread = [3 4]	reward = 0.9901	route = [3, 4]
# t = 46, thread = [3 1]	reward = 0.9838	route = [3, 2, 1]
# t = 47, thread = [1 5]	reward = 0.9846	route = [1, 0, 5]
# t = 48, thread = [3 5]	reward = 0.9858	route = [3, 4, 5]
# t = 49, thread = [3 5]	reward = 0.9858	route = [3, 4, 5]
# t = 50, thread = [5 6]	reward = 0.9858	route = [5, 6]
# t = 51, thread = [3 0]	reward = 0.9549	route = [3, 2, 1, 0]
# t = 52, thread = [5 4]	reward = 0.955	route = [5, 4]
# t = 53, thread = [4 1]	reward = 0.9834	route = [4, 1]
# t = 54, thread = [6 4]	reward = 0.9779	route = [6, 4]
# t = 55, thread = [1 0]	reward = 0.9739	route = [1, 0]
# t = 56, thread = [5 2]	reward = 0.9783	route = [5, 4, 3, 2]
# t = 57, thread = [3 4]	reward = 0.9779	route = [3, 4]
# t = 58, thread = [0 4]	reward = 0.9929	route = [0, 1, 4]
# t = 59, thread = [6 4]	reward = 0.983	route = [6, 4]
# t = 60, thread = [1 6]	reward = 0.9835	route = [1, 4, 6]
# t = 61, thread = [6 0]	reward = 0.983	route = [6, 5, 0]
# t = 62, thread = [0 3]	reward = 0.9766	route = [0, 1, 4, 3]
# t = 63, thread = [6 2]	reward = 0.9691	route = [6, 4, 1, 2]
# t = 64, thread = [2 0]	reward = 0.9715	route = [2, 1, 0]
# t = 65, thread = [3 0]	reward = 0.9517	route = [3, 4, 1, 0]
# t = 66, thread = [0 2]	reward = 0.9218	route = [0, 1, 2]
# t = 67, thread = [4 1]	reward = 0.8712	route = [4, 1]
# t = 68, thread = [6 1]	reward = 0.9727	route = [6, 4, 1]
# t = 69, thread = [0 3]	reward = 0.9553	route = [0, 1, 4, 3]
# t = 70, thread = [6 0]	reward = 0.9738	route = [6, 5, 0]
# t = 71, thread = [3 1]	reward = 0.9842	route = [3, 2, 1]
# t = 72, thread = [0 6]	reward = 0.9843	route = [0, 5, 6]
# t = 73, thread = [6 5]	reward = 0.9842	route = [6, 5]
# t = 74, thread = [4 2]	reward = 0.9732	route = [4, 1, 2]
# t = 75, thread = [3 5]	reward = 0.9761	route = [3, 4, 5]
# t = 76, thread = [6 5]	reward = 0.9732	route = [6, 5]
# t = 77, thread = [0 2]	reward = 0.932	route = [0, 1, 2]
# t = 78, thread = [4 6]	reward = 0.9867	route = [4, 6]
# t = 79, thread = [5 2]	reward = 0.9928	route = [5, 4, 3, 2]
# t = 80, thread = [0 4]	reward = 0.9929	route = [0, 1, 4]
# t = 81, thread = [1 6]	reward = 0.9985	route = [1, 4, 6]
# t = 82, thread = [6 5]	reward = 0.9861	route = [6, 5]
# t = 83, thread = [6 2]	reward = 0.9694	route = [6, 4, 7, 2]
# t = 84, thread = [0 6]	reward = 0.9694	route = [0, 5, 6]
# t = 85, thread = [6 1]	reward = 0.9639	route = [6, 4, 1]
# t = 86, thread = [1 3]	reward = 0.9732	route = [1, 2, 3]
# t = 87, thread = [4 2]	reward = 0.9118	route = [4, 1, 2]
# t = 88, thread = [0 2]	reward = 0.8682	route = [0, 1, 2]
# t = 89, thread = [0 3]	reward = 0.8757	route = [0, 1, 2, 3]
# t = 90, thread = [4 3]	reward = 0.876	route = [4, 3]
# t = 91, thread = [5 4]	reward = 0.989	route = [5, 4]
# t = 92, thread = [0 2]	reward = 0.9845	route = [0, 1, 2]
# t = 93, thread = [4 6]	reward = 0.9835	route = [4, 6]
# t = 94, thread = [2 4]	reward = 0.9829	route = [2, 7, 4]
# t = 95, thread = [3 4]	reward = 0.9828	route = [3, 4]
# t = 96, thread = [6 2]	reward = 0.9707	route = [6, 4, 7, 2]
# t = 97, thread = [2 5]	reward = 0.9709	route = [2, 3, 4, 5]
# t = 98, thread = [3 1]	reward = 0.9845	route = [3, 2, 1]
# t = 99, thread = [1 4]	reward = 0.9822	route = [1, 4]
#
# reward = 0.9651509461154372

# %%
# Недополученные награды на каждом шаге t
# Выводит разность между максимально возможной и реально полученной наградой на каждом шаге t

lost_rewards_ecmp = []     # (max - current) - недополученная награда на каждом шаге
for t in range(1, T):
    v_src, v_dst = Times_test[t][0:2]

    rewards_t = []
    for path in paths[v_src][v_dst]:
        N_t = copy.deepcopy(N[t - 1]) # N до прихода t-го потока

        for k in range(len(path) - 1):
            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            v = path[k]
            action = E_v[v].index(path[k + 1])
            add_thread_N(N_t[v], v_src, v_dst, action, dt)

        L = [calculate_queues_load(N_t, v) for v in V]

        rewards_t.append(get_reward(L))

    lost_rewards_ecmp.append(max(rewards_t) - rewards[t])

# %%
with open(f'{PATH}lost_rewards_ecmp.pickle', 'wb') as f:
   pickle.dump(lost_rewards_ecmp, f)

# %%
with open('/content/drive/MyDrive/marl/2/lost_rewards.pickle', 'rb') as f:
    lost_rewards_easy = pickle.load(f)

with open(f'/content/drive/MyDrive/marl/3/lost_rewards.pickle', 'rb') as f:
    lost_rewards_hard = pickle.load(f)

# %%
lost_rewards_ecmp = np.cumsum(lost_rewards) / T / (max_reward - min_reward)

plt.title('Недополученная масштабированная награда')
plt.xlabel('t')
plt.ylabel('max_r(t) - r(t)')
plt.grid()
plt.ylim([0, 0.07])

plt.plot(np.arange(T - 1), lost_rewards_ecmp, label='ECMP')
plt.plot(np.arange(T - 1), lost_rewards_easy, label='С централизованным знанием сети')
plt.plot(np.arange(T - 1), lost_rewards_hard, label='Без централизованного знания сети')

plt.legend()
plt.show()
