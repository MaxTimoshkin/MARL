# %%
from collections import deque

import random
import pickle
import copy

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
G = nx.Graph()

V = [0, 1, 2, 3, 4, 5, 6, 7]
E = [[0, 1], [0, 5], [1, 2], [1, 4], [2, 3], [3, 4], [2, 7], [4, 5], [5, 6], [4, 6], [4, 7]]

positions = [(0.5, -0.5), (1, 0), (2, 0), (2, 1), (1, 1), (0.5, 0.5), (0, 1), (1.5, 0.5)]

for v in V:
    G.add_node(v, pos=positions[v])

G.add_edges_from(E)

pos = nx.get_node_attributes(G, 'pos')

# %%
nx.draw(G, pos, with_labels=True)
plt.show()

# %%
# Для каждой вершины формируем множество вершин, в которые можно попасть из данной
E_v = [set() for _ in V]

for e in np.concatenate([E, np.flip(E, axis=1)]):
    E_v[e[0]].add(e[1])

E_v = [list(E_v[v]) for v in V]
E_v
# Out:
# [[1, 5],
#  [0, 2, 4],
#  [1, 3, 7],
#  [2, 4],
#  [1, 3, 5, 6, 7],
#  [0, 4, 6],
#  [4, 5],
#  [2, 4]]

# %%
# Находит множество путей в графе из вершины start в вершину end без циклов
def find_paths(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if start not in graph:
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            new_paths = find_paths(graph, node, end, path)
            for new_path in new_paths:
                paths.append(new_path)
    return paths


# Находит множество допустимых вершин для построенного множества путей valid_paths и текущего маршрута current_route
def find_next_vertices(valid_paths, current_route):
    next_vertices = set()

    for path in valid_paths:
        if len(path) > len(current_route) and path[:len(current_route)] == current_route:
            next_vertex = path[len(current_route)]
            next_vertices.add(next_vertex)

    return next_vertices

# %%
# Формирование множеств путей для каждого потока (v_src, v_dst) в графе без циклов
# paths[v_src][v_dst]
paths =  [None] * len(V)
for v_src in range(len(V)):
    paths[v_src] =  [None] * len(V)
    for v_dst in range(len(V)):
        if v_src != v_dst:
            paths[v_src][v_dst] = find_paths(G, v_src, v_dst)

# %%
μ = 1          # Параметр интенсивности обслуживания каждого выходного порта коммутатора
S = 5          # Максимальный размер очереди

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
λ = np.random.rand(len(V), len(V)).round(2) / 2   # Параметры интенсивности каждого потока
np.fill_diagonal(λ, 0)                            # Диагональные элементы не используются
λ
# Out:
# array([[0.   , 0.475, 0.365, 0.3  , 0.08 , 0.08 , 0.03 , 0.435],
#        [0.3  , 0.   , 0.01 , 0.485, 0.415, 0.105, 0.09 , 0.09 ],
#        [0.15 , 0.26 , 0.   , 0.145, 0.305, 0.07 , 0.145, 0.185],
#        [0.23 , 0.395, 0.1  , 0.   , 0.295, 0.025, 0.305, 0.085],
#        [0.035, 0.475, 0.485, 0.405, 0.   , 0.05 , 0.34 , 0.22 ],
#        [0.06 , 0.25 , 0.015, 0.455, 0.13 , 0.   , 0.155, 0.26 ],
#        [0.275, 0.09 , 0.485, 0.39 , 0.47 , 0.445, 0.   , 0.46 ],
#        [0.045, 0.1  , 0.025, 0.165, 0.195, 0.135, 0.415, 0.   ]])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# DQN Agent
class DQNAgent(nn.Module):
    def __init__(self, state_shape, n_actions):
        super().__init__()
        self.n_actions = n_actions
        self.state_shape = state_shape

        self.network = nn.Sequential(
            nn.Linear(state_shape, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions),
        )

    def forward(self, x):
        return self.network(x)

    def get_action(self, state, E_v, E_valid, device=device):
        state_t = torch.tensor(state, device=device, dtype=torch.float32)
        mask = np.zeros(self.n_actions)
        invalid_idxs = [E_v.index(idx) for idx in list(set(E_v) - E_valid)]
        mask[invalid_idxs] = -float("Inf")
        return (self.forward(state_t).detach().cpu().numpy() + mask).argmax()

    def eps_greedy_action(self, state, epsilon, E_v, E_valid, device=device):
        if random.random() < epsilon:
            action = E_v.index(np.random.choice(list(E_valid)))
        else:
            action = self.get_action(state, E_v, E_valid)
        return action


# Replay Buffer
class ReplayBuffer(object):
    def __init__(self, size):
        self._storage = deque(maxlen=size)

    def __len__(self):
        return len(self._storage)

    def add(self, transition):
        self._storage.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self._storage, batch_size)
        states, actions, rewards, next_states = zip(*batch)
        return np.array(states), np.array(actions), np.array(rewards), np.array(next_states)

# %%
#state_dim = 4 * len(V) + 2 * len(E)

agents = [None] * len(V)
target_networks = [None] * len(V)

for v in V:
    state_dim = 4 * len(V) + len(E_v[v])        ####################
    n_actions = len(E_v[v])
    agents[v] = DQNAgent(state_dim, n_actions).to(device)
    target_networks[v] = DQNAgent(state_dim, n_actions).to(device)
    target_networks[v].load_state_dict(agents[v].state_dict())

optimizers = [torch.optim.Adam(agents[v].parameters(), lr=1e-4) for v in V]
exp_replays = [ReplayBuffer(2000) for v in V]

# %%
# Возвращает temporal difference loss
def compute_td_loss(states, actions, rewards, next_states,
                    agent, target_network, gamma=0.5, device=device):

    states = torch.tensor(states, device=device, dtype=torch.float32)                # shape: [batch_size, state_dim]
    actions = torch.tensor(actions, device=device, dtype=torch.int64)                # shape: [batch_size]
    rewards = torch.tensor(rewards, device=device, dtype=torch.float32)              # shape: [batch_size]
    next_states = torch.tensor(next_states, device=device, dtype=torch.float)        # shape: [batch_size, state_dim]

    predicted_qvalues = agent(states)                                                # shape: [batch_size, n_actions]
    predicted_next_qvalues = target_network(next_states)                             # shape: [batch_size, n_actions]
    predicted_qvalues_for_actions = predicted_qvalues[range(len(actions)), actions]  # shape: [batch_size]
    next_state_values = predicted_next_qvalues.max(axis=1).values
    target_qvalues_for_actions = rewards + gamma * next_state_values
    return torch.mean((predicted_qvalues_for_actions - target_qvalues_for_actions.detach()) ** 2) #loss


# Рассчитывает среднюю длину очереди каждого выходного порта
def loading_queue(ρ, s):
    return np.sum([k * ρ ** (k + 1) for k in range(1, s + 1)], axis=0) / np.sum([(ρ ** k) for k in range(s + 2)], axis=0)


# Возвращает OHE-вектор для потока (v_src, v_dst)
def OHE_thread(v_src, v_dst):
    OHE_n = np.zeros((2, len(V)))
    OHE_n[0, v_src] = 1
    OHE_n[1, v_dst] = 1
    return OHE_n.reshape(-1)


# Рассчитывает epsilon на текущем шаге step
def linear_decay(init_epsilon, final_epsilon, step, decay_steps):
    return max(init_epsilon - step * (init_epsilon - final_epsilon) / decay_steps, final_epsilon)


# Возвращает загруженность L[v] выходных портов q коммутатора v
# основываясь на информации N[v] о поступающих потоках на коммутатор v
def calculate_queues_load(N, v):
    λ_v = np.zeros(len(E_v[v]))
    np.add.at(λ_v, N[v]['q'], λ[N[v]['n'][:, 0], N[v]['n'][:, 1]])
    return loading_queue(λ_v / μ, S) / S


# Принимает загруженности очередей коммутаторов L[v][q]. Возвращает reward
def get_reward(L):
    L_concat = np.concatenate(L)
    return 1 - np.sqrt(((L_concat - L_concat.mean()) ** 2).mean())


# Генерирует потоки в сети: возвращает матрицу размера (T, 3) со столбцами (v_src, v_dst, dt)
def generate_treads(T):
    Times = np.zeros((T, 3), dtype=int)
    Times[:, 0:2] = np.random.randint(0, len(V) - 1, (T, 2))    # v_src, v_dst
    mask = Times[:, 0] == Times[:, 1]

    while np.any(mask):
        Times[:, 0:2][mask] = np.random.randint(0, len(V) - 1, (np.sum(mask), 2))
        mask = Times[:, 0] == Times[:, 1]

    Times[:, 2] = np.random.randint(2, 8, size=T)               # dt
    return Times

# %%
# Гиперпараметры метода DQN

batch_size = 256
total_steps = 50_001

decay_steps = 30_000
init_epsilon = 1
final_epsilon = 0.02

loss_freq = 400
refresh_target_network_freq = 100
eval_freq = 400

max_grad_norm = 50

# %%
# Загруженность оцередей каждого коммутатора L[v][q]
L = [np.zeros(len(E_v[v])) for v in range(len(V))]

# Это тройка массивов [n, q, t] для каждого коммутатора v (содержит информацию о поступающих потоках на коммутаторы), где
#   n = (v_src, v_dst) - потоки, поступающие на коммутатор v;
#   q - выходные порты, на который отправляются пакеты потоков n (0, 1, 2, ...);
#   t - оставшееся время поступления пакетов потоков n.
N = [{'n': np.zeros((0, 2), dtype=np.int32),
      'q': np.zeros(0, dtype=np.int32),
      't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]

Times = generate_treads(total_steps)

# %%
# Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
def update_N(N):
    for v in V:
        N[v]['t'] = N[v]['t'] - 1
        non_zero_idxs = np.where(N[v]['t'] != 0)[0]
        N[v]['n'] = N[v]['n'][non_zero_idxs]
        N[v]['q'] = N[v]['q'][non_zero_idxs]
        N[v]['t'] = N[v]['t'][non_zero_idxs]

# Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
def add_thread_N(N_v, v_src, v_dst, action, dt):
    N_v['n'] = np.vstack([N_v['n'], [v_src, v_dst]])
    N_v['q'] = np.append(N_v['q'], action)
    N_v['t'] = np.append(N_v['t'], dt)

# %% [markdown]
# # Создание валидационной выборки для оценки качества

# %%
# Рассчитывает максимальный ('argmax') или минимальный ('argmin') reward, выбирая оптимальные действия на каждом шаге t
def get_max_min_optimal_reward(Times, optimal='argmax', verbose=False):
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [{'n': np.zeros((0, 2), dtype=np.int32),
           'q': np.zeros(0, dtype=np.int32),
           't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]
    optimal_rewards = []

    T = Times.shape[0]
    for t in range(T):
        v_src, v_dst, dt = Times[t]

        rewards_t = []
        N_t = [copy.deepcopy(N) for _ in range(len(paths[v_src][v_dst]))]
        for i, path in enumerate(paths[v_src][v_dst]):
            for k in range(len(path) - 1):
                # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
                v = path[k]
                action = E_v[v].index(path[k + 1])
                add_thread_N(N_t[i][v], v_src, v_dst, action, dt)

            L = [calculate_queues_load(N_t[i], v) for v in V]
            rewards_t.append(get_reward(L))

        if optimal == 'argmax': best_route = np.argmax(rewards_t)
        if optimal == 'argmin': best_route = np.argmin(rewards_t)
        if verbose:
            print(f"t = {t}\t reward = {round(rewards_t[best_route], 3)}\t route = {paths[v_src][v_dst][best_route]}")
        N = copy.deepcopy(N_t[best_route])
        optimal_rewards.append(rewards_t[best_route])

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N)

        L = [calculate_queues_load(N, v) for v in V]

    return sum(optimal_rewards)

# %%
# Оценивает среднюю награду на валидационной выборке потоков Times (Действия выбираются только жадно)
def evaluate(Times):
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [{'n': np.zeros((0, 2), dtype=np.int32),
          'q': np.zeros(0, dtype=np.int32),
          't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))]
    rewards = []

    T = Times.shape[0]
    for t in range(T):
        v_src, v_dst, dt = Times[t]
        v = v_src

        route = []
        while v != v_dst:
            route.append(v)

            # Формирование состояния для подачи на вход нейронке:
            # OHE поступающего потока | Sum OHE всех поступающих потоков на коммутатор | Загруженность во всей сети L
            OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[v]['n']], axis=0)
            #state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])
            state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, L[v]])               ####################

            # Выбор действия жадно
            E_valid = find_next_vertices(paths[v_src][v_dst], route)
            action = agents[v].get_action(state, E_v[v], E_valid)

            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            add_thread_N(N[v], v_src, v_dst, action, dt)

            # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
            L[v] = calculate_queues_load(N, v)

            # Переход на выбранный коммутатор
            v = E_v[v][action]

        # Расчет награды и ее добавление в список
        rewards.append(get_reward(L))

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N)

        L = [calculate_queues_load(N, v) for v in V]

    return sum(rewards) / T

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
T = 100    # t = 0..T, T - общее количество временных шагов
Times_test = generate_treads(T)

max_reward = get_max_min_optimal_reward(Times_test, 'argmax') / T
min_reward = get_max_min_optimal_reward(Times_test, 'argmin') / T

print(f"max reward = {max_reward}")
print(f"min reward = {min_reward}")
# Out:
# max reward = 0.9759624377243478
# min reward = 0.8919704050626504

# %% [markdown]
# # Обучение

# %%
transitions = [[] for _ in V]

PATH = f'/content/drive/MyDrive/marl/3/'
MAX_reward = 0

loss_values = []
reward_values = []

for t in range(total_steps):
    v_src, v_dst, dt = Times[t]
    v = v_src

    route = []
    while v != v_dst:
        route.append(v)

        # Формирование состояния для подачи на вход нейронке:
        # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
        OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[v]['n']], axis=0)
        #state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])
        state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, L[v]])               ###################

        # Выбор действия. eps-жадная стратегия
        E_valid = find_next_vertices(paths[v_src][v_dst], route)
        epsilon = linear_decay(init_epsilon, final_epsilon, t, decay_steps)
        action = agents[v].eps_greedy_action(state, epsilon, E_v[v], E_valid)

        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        add_thread_N(N[v], v_src, v_dst, action, dt)

        # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
        L[v] = calculate_queues_load(N, v)

        if len(transitions[v]) > 0:
            transitions[v].append(state)  #next_state
            exp_replays[v].add(transitions[v])
        transitions[v] = [state, action]

        v = E_v[v][action]

    # Расчет награды и добавление ее в переходы всем агентам маршрута
    reward = get_reward(L)
    for v in route:
        transitions[v].append(reward)

    # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
    update_N(N)

    # Рассчитывает загруженность L[v][q] для каждого выходного порта q коммутатора v
    L = [calculate_queues_load(N, v) for v in V]

    # Обучение каждого коммутатора отдельно
    losses = []
    for v in V:
        if len(exp_replays[v]) >= batch_size:
            states, actions, rewards, next_states = exp_replays[v].sample(batch_size)
            loss = compute_td_loss(states, actions, rewards, next_states, agents[v], target_networks[v])

            loss.backward()
            if t % loss_freq == 0:
                losses.append(loss.data.cpu().item())
            grad_norm = nn.utils.clip_grad_norm_(agents[v].parameters(), max_grad_norm)
            optimizers[v].step()
            optimizers[v].zero_grad()

            # Каждые refresh_target_network_freq обновляются веса ОДНОЙ target сети
            # (Добавляет некоторую стабильность по сравнению с тем, если бы они обновлялись все разом)
            if t % refresh_target_network_freq == 0:
                for v in V:
                    if t % (refresh_target_network_freq * len(V)) == refresh_target_network_freq * v:
                        target_networks[v].load_state_dict(agents[v].state_dict())

    # Вывод лосса с заданной частотой
    if t % loss_freq == 0:
        loss_values.append(losses)
        losses = np.array(losses).round(5)
        print(f"t = {str(t):5}\t losses = {losses}")

    # Вывод масштабированной награды на валидационной выборке с заданной частотой
    if t % eval_freq == 0:
        scaled_reward = (evaluate(Times_test) - min_reward) / (max_reward - min_reward)
        reward_values.append(scaled_reward)
        print(f"t = {str(t):5}\t reward = {round(scaled_reward, 4)}\t eps = {round(epsilon, 4)}\n")

        if scaled_reward > MAX_reward:
            MAX_reward = scaled_reward
            for v in V:
                torch.save(agents[v].state_dict(), PATH + f'model_{v}')
                torch.save(optimizers[v].state_dict(), PATH + f'opt_{v}')
# Out:
# t = 0    	 losses = []
# t = 0    	 reward = 0.4611	 eps = 1.0
#
# t = 400  	 losses = [0.41241]
# t = 400  	 reward = 0.4468	 eps = 0.9869
#
# t = 800  	 losses = [0.01275 0.00569 0.00884 0.00543 0.00682]
# t = 800  	 reward = 0.6664	 eps = 0.9739
#
# t = 1200 	 losses = [0.00437 0.00276 0.00367 0.00636 0.14546 0.00141 0.00203 0.01751]
# t = 1200 	 reward = 0.7985	 eps = 0.9608
#
# t = 1600 	 losses = [0.00248 0.00167 0.0021  0.00198 0.00192 0.00195 0.00146 0.00234]
# t = 1600 	 reward = 0.7712	 eps = 0.9477
#
# t = 2000 	 losses = [0.00183 0.00152 0.00208 0.00142 0.03431 0.00126 0.00093 0.00123]
# t = 2000 	 reward = 0.7505	 eps = 0.9347
#
# t = 2400 	 losses = [0.00133 0.0011  0.00107 0.00104 0.00085 0.00117 0.00097 0.00151]
# t = 2400 	 reward = 0.7578	 eps = 0.9216
#
# t = 2800 	 losses = [0.00099 0.00093 0.00105 0.00109 0.00884 0.00098 0.00082 0.00113]
# t = 2800 	 reward = 0.8457	 eps = 0.9085
#
# t = 3200 	 losses = [0.00133 0.00072 0.00097 0.00122 0.00072 0.00068 0.00084 0.00142]
# t = 3200 	 reward = 0.7896	 eps = 0.8955
#
# t = 3600 	 losses = [0.00091 0.00084 0.00085 0.00116 0.00235 0.00073 0.00077 0.00105]
# t = 3600 	 reward = 0.7946	 eps = 0.8824
#
# t = 4000 	 losses = [0.00062 0.0007  0.00073 0.00105 0.00053 0.00089 0.00079 0.0009 ]
# t = 4000 	 reward = 0.8003	 eps = 0.8693
#
# t = 4400 	 losses = [0.00068 0.0007  0.00074 0.0013  0.00099 0.00055 0.00093 0.0008 ]
# t = 4400 	 reward = 0.7695	 eps = 0.8563
#
# t = 4800 	 losses = [0.00069 0.00056 0.00064 0.00096 0.00057 0.00077 0.00087 0.00106]
# t = 4800 	 reward = 0.7613	 eps = 0.8432
#
# t = 5200 	 losses = [0.00089 0.00057 0.00052 0.00092 0.00045 0.00063 0.00075 0.00093]
# t = 5200 	 reward = 0.8019	 eps = 0.8301
#
# t = 5600 	 losses = [0.00078 0.00051 0.0007  0.00096 0.00038 0.00056 0.00066 0.00066]
# t = 5600 	 reward = 0.7654	 eps = 0.8171
#
# t = 6000 	 losses = [0.00068 0.00044 0.00062 0.00112 0.00031 0.00052 0.0006  0.00143]
# t = 6000 	 reward = 0.7857	 eps = 0.804
#
# t = 6400 	 losses = [0.0006  0.00042 0.00056 0.00096 0.00024 0.00046 0.0006  0.00103]
# t = 6400 	 reward = 0.7898	 eps = 0.7909
#
# t = 6800 	 losses = [0.00066 0.00036 0.00043 0.00085 0.00032 0.0003  0.00075 0.00084]
# t = 6800 	 reward = 0.8345	 eps = 0.7779
#
# t = 7200 	 losses = [0.00054 0.00048 0.00054 0.00091 0.00021 0.00051 0.00074 0.00078]
# t = 7200 	 reward = 0.7606	 eps = 0.7648
#
# t = 7600 	 losses = [0.00061 0.00049 0.00068 0.00104 0.00033 0.00021 0.00087 0.00088]
# t = 7600 	 reward = 0.7476	 eps = 0.7517
#
# t = 8000 	 losses = [0.00041 0.0004  0.00052 0.00086 0.00025 0.0004  0.00081 0.00066]
# t = 8000 	 reward = 0.7824	 eps = 0.7387
#
# t = 8400 	 losses = [0.00069 0.00032 0.00041 0.00091 0.00022 0.00031 0.00065 0.00083]
# t = 8400 	 reward = 0.7672	 eps = 0.7256
#
# t = 8800 	 losses = [0.00047 0.00044 0.00055 0.00084 0.00025 0.00035 0.00071 0.00088]
# t = 8800 	 reward = 0.7766	 eps = 0.7125
#
# t = 9200 	 losses = [0.00043 0.00038 0.00031 0.00067 0.00022 0.0004  0.0007  0.00086]
# t = 9200 	 reward = 0.7582	 eps = 0.6995
#
# t = 9600 	 losses = [0.00054 0.00034 0.00038 0.00081 0.00021 0.00036 0.00064 0.00067]
# t = 9600 	 reward = 0.7452	 eps = 0.6864
#
# t = 10000	 losses = [0.00035 0.00027 0.00034 0.00069 0.00024 0.00037 0.00078 0.00091]
# t = 10000	 reward = 0.7744	 eps = 0.6733
#
# t = 10400	 losses = [0.00042 0.00033 0.00042 0.00064 0.00019 0.00048 0.00067 0.00068]
# t = 10400	 reward = 0.7629	 eps = 0.6603
#
# t = 10800	 losses = [0.00046 0.00026 0.00032 0.00075 0.00026 0.00032 0.00055 0.00101]
# t = 10800	 reward = 0.765	 eps = 0.6472
#
# t = 11200	 losses = [0.00035 0.00025 0.00039 0.00057 0.00018 0.00028 0.00045 0.00078]
# t = 11200	 reward = 0.8191	 eps = 0.6341
#
# t = 11600	 losses = [0.00066 0.0003  0.00033 0.00068 0.00021 0.00026 0.00057 0.00081]
# t = 11600	 reward = 0.7589	 eps = 0.6211
#
# t = 12000	 losses = [0.00046 0.00032 0.00039 0.00073 0.0002  0.0003  0.00057 0.00069]
# t = 12000	 reward = 0.7885	 eps = 0.608
#
# t = 12400	 losses = [0.00037 0.0002  0.00025 0.00086 0.00021 0.00024 0.00061 0.00058]
# t = 12400	 reward = 0.8112	 eps = 0.5949
#
# t = 12800	 losses = [0.00039 0.00029 0.00036 0.00048 0.00017 0.0003  0.00068 0.00068]
# t = 12800	 reward = 0.7483	 eps = 0.5819
#
# t = 13200	 losses = [0.00039 0.00033 0.00046 0.00079 0.00023 0.00021 0.00051 0.00053]
# t = 13200	 reward = 0.7469	 eps = 0.5688
#
# t = 13600	 losses = [0.00037 0.00026 0.00057 0.00067 0.00022 0.00026 0.00087 0.00053]
# t = 13600	 reward = 0.7785	 eps = 0.5557
#
# t = 14000	 losses = [0.00046 0.00023 0.00035 0.00057 0.00026 0.00024 0.00042 0.00051]
# t = 14000	 reward = 0.7319	 eps = 0.5427
#
# t = 14400	 losses = [0.0004  0.00033 0.00024 0.00053 0.00011 0.00032 0.00051 0.00053]
# t = 14400	 reward = 0.7819	 eps = 0.5296
#
# t = 14800	 losses = [0.00043 0.00032 0.0003  0.00057 0.00021 0.0002  0.00058 0.00074]
# t = 14800	 reward = 0.7711	 eps = 0.5165
#
# t = 15200	 losses = [0.00042 0.00024 0.00024 0.00062 0.00015 0.00017 0.0004  0.00048]
# t = 15200	 reward = 0.7483	 eps = 0.5035
#
# t = 15600	 losses = [0.00038 0.0003  0.00028 0.00086 0.00019 0.00029 0.00048 0.00048]
# t = 15600	 reward = 0.768	 eps = 0.4904
#
# t = 16000	 losses = [0.00046 0.00024 0.00023 0.0006  0.00013 0.00029 0.00053 0.00066]
# t = 16000	 reward = 0.7674	 eps = 0.4773
#
# t = 16400	 losses = [0.00036 0.00026 0.00043 0.00072 0.00027 0.00023 0.00046 0.00048]
# t = 16400	 reward = 0.7829	 eps = 0.4643
#
# t = 16800	 losses = [0.00025 0.00018 0.00044 0.00057 0.00016 0.00028 0.00045 0.00093]
# t = 16800	 reward = 0.7114	 eps = 0.4512
#
# t = 17200	 losses = [0.00036 0.00029 0.00027 0.00052 0.00016 0.00021 0.00053 0.00062]
# t = 17200	 reward = 0.732	 eps = 0.4381
#
# t = 17600	 losses = [0.00044 0.0003  0.00028 0.00049 0.00016 0.00038 0.00048 0.00071]
# t = 17600	 reward = 0.7696	 eps = 0.4251
#
# t = 18000	 losses = [0.00038 0.00037 0.00053 0.00068 0.00019 0.00024 0.00055 0.00061]
# t = 18000	 reward = 0.8199	 eps = 0.412
#
# t = 18400	 losses = [0.00043 0.00026 0.00034 0.0009  0.00013 0.00022 0.00056 0.00056]
# t = 18400	 reward = 0.7282	 eps = 0.3989
#
# t = 18800	 losses = [0.00043 0.00021 0.00035 0.00054 0.00021 0.00029 0.00046 0.0007 ]
# t = 18800	 reward = 0.7299	 eps = 0.3859
#
# t = 19200	 losses = [0.0003  0.00024 0.00036 0.00048 0.00014 0.00023 0.00059 0.0007 ]
# t = 19200	 reward = 0.7359	 eps = 0.3728
#
# t = 19600	 losses = [0.0003  0.00025 0.00049 0.00066 0.00014 0.0003  0.00042 0.00078]
# t = 19600	 reward = 0.7983	 eps = 0.3597
#
# t = 20000	 losses = [0.0005  0.00026 0.0003  0.00061 0.00016 0.00026 0.00058 0.0009 ]
# t = 20000	 reward = 0.8179	 eps = 0.3467
#
# t = 20400	 losses = [0.00043 0.0002  0.0004  0.00058 0.0002  0.00033 0.00046 0.00069]
# t = 20400	 reward = 0.8136	 eps = 0.3336
#
# t = 20800	 losses = [0.00038 0.00029 0.00031 0.00053 0.00011 0.00026 0.00046 0.00066]
# t = 20800	 reward = 0.8814	 eps = 0.3205
#
# t = 21200	 losses = [0.00026 0.0002  0.00026 0.00057 0.00015 0.00033 0.00038 0.00051]
# t = 21200	 reward = 0.8375	 eps = 0.3075
#
# t = 21600	 losses = [0.0003  0.00017 0.00034 0.00055 0.00012 0.00047 0.00051 0.00064]
# t = 21600	 reward = 0.7771	 eps = 0.2944
#
# t = 22000	 losses = [0.0005  0.00019 0.00036 0.00056 0.0002  0.00031 0.00058 0.00055]
# t = 22000	 reward = 0.8427	 eps = 0.2813
#
# t = 22400	 losses = [0.00047 0.0002  0.0003  0.00048 0.0001  0.00033 0.00051 0.00052]
# t = 22400	 reward = 0.7822	 eps = 0.2683
#
# t = 22800	 losses = [0.00039 0.00024 0.00031 0.00065 0.0002  0.00031 0.0005  0.00067]
# t = 22800	 reward = 0.7047	 eps = 0.2552
#
# t = 23200	 losses = [0.00037 0.00018 0.00027 0.00051 0.00016 0.00032 0.00042 0.00068]
# t = 23200	 reward = 0.7947	 eps = 0.2421
#
# t = 23600	 losses = [0.00034 0.00019 0.00023 0.00052 0.00014 0.00022 0.00031 0.00062]
# t = 23600	 reward = 0.8283	 eps = 0.2291
#
# t = 24000	 losses = [0.00048 0.00016 0.0003  0.00046 0.00011 0.00024 0.00043 0.00069]
# t = 24000	 reward = 0.8415	 eps = 0.216
#
# t = 24400	 losses = [0.00039 0.00019 0.00028 0.00059 0.00025 0.00022 0.00051 0.00056]
# t = 24400	 reward = 0.7707	 eps = 0.2029
#
# t = 24800	 losses = [0.00033 0.00017 0.0003  0.00051 0.00017 0.00025 0.0006  0.0005 ]
# t = 24800	 reward = 0.7943	 eps = 0.1899
#
# t = 25200	 losses = [0.00045 0.00017 0.00035 0.0005  0.00019 0.00024 0.00041 0.00054]
# t = 25200	 reward = 0.7866	 eps = 0.1768
#
# t = 25600	 losses = [0.00037 0.00019 0.00028 0.00044 0.00011 0.00023 0.00047 0.00068]
# t = 25600	 reward = 0.7989	 eps = 0.1637
#
# t = 26000	 losses = [0.00037 0.00022 0.00028 0.00053 0.00023 0.00036 0.0004  0.00053]
# t = 26000	 reward = 0.8283	 eps = 0.1507
#
# t = 26400	 losses = [0.0004  0.00021 0.00022 0.00066 0.0001  0.00032 0.00031 0.00073]
# t = 26400	 reward = 0.8441	 eps = 0.1376
#
# t = 26800	 losses = [0.00039 0.00032 0.00025 0.00043 0.0002  0.00021 0.00043 0.00043]
# t = 26800	 reward = 0.8054	 eps = 0.1245
#
# t = 27200	 losses = [4.4e-04 2.3e-04 3.9e-04 5.1e-04 8.0e-05 3.8e-04 4.4e-04 6.2e-04]
# t = 27200	 reward = 0.8344	 eps = 0.1115
#
# t = 27600	 losses = [0.00049 0.00026 0.00031 0.00054 0.00018 0.0002  0.00045 0.00048]
# t = 27600	 reward = 0.8348	 eps = 0.0984
#
# t = 28000	 losses = [0.00043 0.00027 0.0003  0.00039 0.00013 0.00026 0.00038 0.00049]
# t = 28000	 reward = 0.7658	 eps = 0.0853
#
# t = 28400	 losses = [0.0004  0.00024 0.00028 0.00069 0.00015 0.00025 0.00034 0.00038]
# t = 28400	 reward = 0.7649	 eps = 0.0723
#
# t = 28800	 losses = [5.0e-04 2.0e-04 2.7e-04 4.3e-04 6.0e-05 3.1e-04 4.5e-04 5.4e-04]
# t = 28800	 reward = 0.8339	 eps = 0.0592
#
# t = 29200	 losses = [0.00048 0.00017 0.00032 0.00046 0.0001  0.00038 0.00045 0.0005 ]
# t = 29200	 reward = 0.8576	 eps = 0.0461
#
# t = 29600	 losses = [3.6e-04 2.2e-04 2.3e-04 5.5e-04 6.0e-05 2.8e-04 4.5e-04 6.5e-04]
# t = 29600	 reward = 0.836	 eps = 0.0331
#
# t = 30000	 losses = [0.00049 0.00014 0.00031 0.00055 0.00014 0.00049 0.00048 0.00038]
# t = 30000	 reward = 0.8608	 eps = 0.02
#
# t = 30400	 losses = [0.00033 0.00021 0.00036 0.00051 0.00016 0.00019 0.00041 0.00048]
# t = 30400	 reward = 0.8181	 eps = 0.02
#
# t = 30800	 losses = [0.00039 0.00021 0.0002  0.00047 0.00013 0.00036 0.00028 0.00056]
# t = 30800	 reward = 0.8316	 eps = 0.02
#
# t = 31200	 losses = [0.00043 0.00019 0.00026 0.00051 0.0001  0.00029 0.00054 0.00052]
# t = 31200	 reward = 0.8213	 eps = 0.02
#
# t = 31600	 losses = [0.00037 0.00019 0.00017 0.00045 0.00015 0.00027 0.0004  0.00053]
# t = 31600	 reward = 0.8721	 eps = 0.02
#
# t = 32000	 losses = [0.00032 0.00019 0.00025 0.00051 0.00016 0.00027 0.00055 0.0005 ]
# t = 32000	 reward = 0.8723	 eps = 0.02
#
# t = 32400	 losses = [0.00045 0.00025 0.00022 0.00049 0.00015 0.00025 0.00039 0.00059]
# t = 32400	 reward = 0.8293	 eps = 0.02
#
# t = 32800	 losses = [0.00029 0.00022 0.00031 0.00041 0.00012 0.00025 0.00054 0.00056]
# t = 32800	 reward = 0.8348	 eps = 0.02
#
# t = 33200	 losses = [0.00029 0.00018 0.00034 0.00042 0.00016 0.00026 0.0003  0.00042]
# t = 33200	 reward = 0.8184	 eps = 0.02
#
# t = 33600	 losses = [0.0003  0.00016 0.0003  0.00042 0.00013 0.00028 0.00043 0.0004 ]
# t = 33600	 reward = 0.8145	 eps = 0.02
#
# t = 34000	 losses = [0.00035 0.00022 0.00031 0.00039 0.00013 0.00024 0.00036 0.00058]
# t = 34000	 reward = 0.8466	 eps = 0.02
#
# t = 34400	 losses = [0.00032 0.00017 0.00025 0.00042 0.00012 0.00027 0.00037 0.00041]
# t = 34400	 reward = 0.8012	 eps = 0.02
#
# t = 34800	 losses = [0.00039 0.00013 0.0002  0.00041 0.00014 0.00019 0.00037 0.00041]
# t = 34800	 reward = 0.8215	 eps = 0.02
#
# t = 35200	 losses = [3.4e-04 1.9e-04 2.4e-04 4.4e-04 9.0e-05 2.1e-04 3.9e-04 5.0e-04]
# t = 35200	 reward = 0.7488	 eps = 0.02
#
# t = 35600	 losses = [0.00039 0.00015 0.00025 0.00033 0.00011 0.00028 0.0003  0.00044]
# t = 35600	 reward = 0.8583	 eps = 0.02
#
# t = 36000	 losses = [2.5e-04 1.7e-04 2.0e-04 4.3e-04 7.0e-05 1.6e-04 4.0e-04 5.5e-04]
# t = 36000	 reward = 0.8651	 eps = 0.02
#
# t = 36400	 losses = [0.00036 0.00022 0.00026 0.0004  0.00017 0.00027 0.00046 0.00043]
# t = 36400	 reward = 0.9022	 eps = 0.02
#
# t = 36800	 losses = [3.4e-04 2.1e-04 3.1e-04 3.4e-04 8.0e-05 2.9e-04 3.8e-04 5.2e-04]
# t = 36800	 reward = 0.885	 eps = 0.02
#
# t = 37200	 losses = [0.00038 0.00026 0.00023 0.00045 0.00012 0.00027 0.00032 0.00034]
# t = 37200	 reward = 0.8943	 eps = 0.02
#
# t = 37600	 losses = [2.5e-04 2.2e-04 2.3e-04 3.6e-04 9.0e-05 2.5e-04 3.0e-04 3.6e-04]
# t = 37600	 reward = 0.9071	 eps = 0.02
#
# t = 38000	 losses = [0.00035 0.00025 0.00021 0.00045 0.00011 0.00031 0.00027 0.00052]
# t = 38000	 reward = 0.9129	 eps = 0.02
#
# t = 38400	 losses = [2.5e-04 1.7e-04 3.0e-04 4.9e-04 7.0e-05 2.7e-04 3.4e-04 3.5e-04]
# t = 38400	 reward = 0.8833	 eps = 0.02
#
# t = 38800	 losses = [0.00026 0.00015 0.00031 0.00037 0.0001  0.00024 0.00021 0.00038]
# t = 38800	 reward = 0.8807	 eps = 0.02
#
# t = 39200	 losses = [2.3e-04 2.3e-04 2.2e-04 2.6e-04 7.0e-05 2.9e-04 2.8e-04 3.8e-04]
# t = 39200	 reward = 0.8649	 eps = 0.02
#
# t = 39600	 losses = [0.00033 0.00021 0.00024 0.00031 0.00011 0.00027 0.00031 0.00041]
# t = 39600	 reward = 0.8653	 eps = 0.02
#
# t = 40000	 losses = [2.9e-04 2.2e-04 3.2e-04 2.9e-04 9.0e-05 2.5e-04 3.1e-04 4.2e-04]
# t = 40000	 reward = 0.8697	 eps = 0.02
#
# t = 40400	 losses = [0.00034 0.00025 0.00036 0.00039 0.00011 0.00021 0.00023 0.00032]
# t = 40400	 reward = 0.8882	 eps = 0.02
#
# t = 40800	 losses = [3.3e-04 2.2e-04 2.6e-04 4.0e-04 7.0e-05 2.1e-04 2.9e-04 3.2e-04]
# t = 40800	 reward = 0.8392	 eps = 0.02
#
# t = 41200	 losses = [0.00032 0.00016 0.00043 0.00025 0.00017 0.0002  0.00027 0.00045]
# t = 41200	 reward = 0.8893	 eps = 0.02
#
# t = 41600	 losses = [2.9e-04 1.8e-04 3.1e-04 3.2e-04 8.0e-05 2.0e-04 3.8e-04 3.6e-04]
# t = 41600	 reward = 0.8931	 eps = 0.02
#
# t = 42000	 losses = [0.00034 0.00018 0.00037 0.00035 0.00019 0.00029 0.00028 0.00033]
# t = 42000	 reward = 0.9263	 eps = 0.02
#
# t = 42400	 losses = [3.3e-04 2.0e-04 3.1e-04 4.1e-04 7.0e-05 2.4e-04 2.2e-04 3.9e-04]
# t = 42400	 reward = 0.9033	 eps = 0.02
#
# t = 42800	 losses = [0.00031 0.00012 0.00028 0.00036 0.00016 0.0002  0.00027 0.00038]
# t = 42800	 reward = 0.9047	 eps = 0.02
#
# t = 43200	 losses = [3.2e-04 1.8e-04 3.2e-04 4.1e-04 8.0e-05 2.5e-04 2.3e-04 3.7e-04]
# t = 43200	 reward = 0.8913	 eps = 0.02
#
# t = 43600	 losses = [0.00031 0.00026 0.00025 0.00048 0.00012 0.00019 0.00038 0.00043]
# t = 43600	 reward = 0.8711	 eps = 0.02
#
# t = 44000	 losses = [0.00038 0.00019 0.00046 0.0004  0.00015 0.00022 0.00034 0.00042]
# t = 44000	 reward = 0.8449	 eps = 0.02
#
# t = 44400	 losses = [0.00033 0.00026 0.0003  0.00039 0.0001  0.00022 0.00026 0.00036]
# t = 44400	 reward = 0.9367	 eps = 0.02
#
# t = 44800	 losses = [2.8e-04 1.5e-04 3.1e-04 3.9e-04 8.0e-05 2.7e-04 2.1e-04 3.9e-04]
# t = 44800	 reward = 0.8959	 eps = 0.02
#
# t = 45200	 losses = [0.00023 0.00017 0.00021 0.00041 0.00016 0.00023 0.00025 0.00049]
# t = 45200	 reward = 0.9131	 eps = 0.02
#
# t = 45600	 losses = [3.1e-04 3.0e-04 2.1e-04 4.2e-04 8.0e-05 2.3e-04 3.0e-04 3.9e-04]
# t = 45600	 reward = 0.9254	 eps = 0.02
#
# t = 46000	 losses = [0.0003  0.00017 0.00024 0.00045 0.00013 0.00021 0.00028 0.0003 ]
# t = 46000	 reward = 0.9033	 eps = 0.02
#
# t = 46400	 losses = [2.7e-04 2.0e-04 2.7e-04 4.0e-04 7.0e-05 2.2e-04 3.7e-04 4.2e-04]
# t = 46400	 reward = 0.8781	 eps = 0.02
#
# t = 46800	 losses = [0.00035 0.00016 0.00025 0.00038 0.00011 0.00019 0.00039 0.00043]
# t = 46800	 reward = 0.8883	 eps = 0.02
#
# t = 47200	 losses = [2.1e-04 1.3e-04 2.4e-04 2.8e-04 9.0e-05 2.7e-04 2.9e-04 3.9e-04]
# t = 47200	 reward = 0.8836	 eps = 0.02
#
# t = 47600	 losses = [0.0003  0.00018 0.00021 0.00038 0.00012 0.00023 0.00027 0.00048]
# t = 47600	 reward = 0.9099	 eps = 0.02
#
# t = 48000	 losses = [4.1e-04 2.3e-04 2.5e-04 3.6e-04 7.0e-05 1.8e-04 3.7e-04 4.4e-04]
# t = 48000	 reward = 0.8999	 eps = 0.02
#
# t = 48400	 losses = [0.00027 0.00019 0.00025 0.00027 0.00017 0.00026 0.00034 0.00033]
# t = 48400	 reward = 0.9475	 eps = 0.02
#
# t = 48800	 losses = [2.9e-04 1.9e-04 2.0e-04 3.0e-04 8.0e-05 2.4e-04 2.9e-04 3.6e-04]
# t = 48800	 reward = 0.9003	 eps = 0.02
#
# t = 49200	 losses = [0.00032 0.00016 0.00026 0.00037 0.00013 0.00019 0.00038 0.00037]
# t = 49200	 reward = 0.9014	 eps = 0.02
#
# t = 49600	 losses = [3.2e-04 1.7e-04 1.6e-04 3.8e-04 9.0e-05 2.0e-04 3.6e-04 3.3e-04]
# t = 49600	 reward = 0.9109	 eps = 0.02
#
# t = 50000	 losses = [2.3e-04 2.0e-04 2.2e-04 5.9e-04 9.0e-05 2.0e-04 2.8e-04 4.1e-04]
# t = 50000	 reward = 0.9009	 eps = 0.02

# %%
#Соранение моделей и оптимизаторов (списки rewards & losses)

with open(f'{PATH}data.pickle', 'wb') as f:
   pickle.dump((reward_values, loss_values), f)

# %% [markdown]
# # Построение графиков зависимостей $r(t)$, $Loss(t)$

# %%
x = range(0, total_steps, eval_freq)

plt.figure(figsize=(12, 8))
plt.title('График зависимости масштабированной награды от времени')
plt.xlabel('t')
plt.ylabel('r(t)')
plt.grid()
plt.ylim([0, 1])
plt.plot(x, reward_values)
plt.show()

# %%
n_delete = 3  # Начинаем с индекса 3, так как ранее не для всех агентов еще был рассчитан loss
loss_values = np.array(loss_values[n_delete:]).T
x = range(n_delete*loss_freq, total_steps, loss_freq)

plt.figure(figsize=(12, 8))
plt.grid()
plt.ylim([0, 0.0025])
plt.title('График зависимости loss от времени')
plt.xlabel('t')
plt.ylabel('loss(t)')

for i, loss in enumerate(loss_values):
    plt.plot(x, loss, label=f'Agent {i+1}')

plt.legend()
plt.show()

# %%
log_losses = np.log(loss_values)

plt.figure(figsize=(12, 8))
plt.grid()
plt.ylim([-11, -4])
plt.title('График зависимости loss(t) в логарифмическом масштабе')
plt.xlabel('t')
plt.ylabel('loss(t)')

for i, losses in enumerate(log_losses):
    plt.plot(x, losses, label=f'Agent {i+1}')

plt.legend()
plt.show()

# %% [markdown]
# #Визуализация графа сети

# %%
# Визуализирует текущее состояние сети. Принимает на вход граф G, информацию о поступающих потоках N.
# Есть возможность выделить маршрут отдельного потока selected_thread=[v_src, v_dst], передав его третьим аргументом
def visualize(G, N, selected_thread=None):
    G = G.to_directed()
    L = [calculate_queues_load(N, v) for v in V]

    # --- Вершины ---
    for u, v in G.edges:
        G[u][v]['weight'] = 0

    # --- Веса вершин ---
    for v_src in V:
        for v_dst in E_v[v_src]:
            G[v_src][v_dst]['weight'] = round(L[v_src][E_v[v_src].index(v_dst)], 3)

    # --- Цвета ---
    for u, v in G.edges:
        G[u][v]['color'] = 'black'

    # --- Выделение маршрута selected_thread ---
    if selected_thread is not None:
        for v_src in V:
            idxs = np.where(np.all(N[v_src]['n'] == selected_thread, axis=1))[0]
            idxs_dst = N[v_src]['q'][idxs]
            for v_dst in np.array(E_v[v_src])[idxs_dst]:
                G[v_src][v_dst]['color'] = 'y'
                G[v_dst][v_src]['color'] = 'y'

    # --- Списки вершин и цветов ---
    colors = nx.get_edge_attributes(G, 'color').values()
    weights = nx.get_edge_attributes(G, 'weight')

    # --- Вывод информации о потоках ---
    print("Текущие потоки в сети:")
    all_n = np.vstack([N[v]['n'] for v in V])
    for (v_src, v_dst) in np.unique(all_n, axis=0):
        print(f"Поток = ({v_src} -> {v_dst}), L = {round(loading_queue(λ[v_src, v_dst] / μ, S) / S, 3)}")

    print()
    if selected_thread is not None:
        v_src, v_dst = selected_thread
        print(f'Выделенный поток = ({v_src} -> {v_dst}), L = {round(loading_queue(λ[v_src, v_dst] / μ, S) / S, 3)}')
    print(f"L_mean = {round(np.concatenate(L).mean(), 4)}, reward = {round(get_reward(L), 4)}")

    # --- Визуализация графа ---
    nx.draw(G, pos, with_labels=True, edge_color=colors)
    nx.draw_networkx_edge_labels(G, pos, weights, label_pos=0.66)
    plt.show()

# %% [markdown]
# # Тестирование и анализ обученных агентов на новой выборке потоков

# %%
# Загрузка сохраненных моделей и параметров оптимизаторов
PATH = f'/content/drive/MyDrive/marl/3/'
for v in V:
    agents[v].load_state_dict(torch.load(PATH + f'model_{v}'))
    optimizers[v].load_state_dict(torch.load(PATH + f'opt_{v}'))

# %%
# with open(f'{PATH}data.pickle', 'rb') as f:
#     data_new = pickle.load(f)

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
T = 100    # t = 0..T, T - общее количество временных шагов
Times_test = generate_treads(T)

# %%
# Создает массив N(t), сохраняющий поступающие потоки в каждый момент времени t, для анализа

L = [np.zeros(len(E_v[v])) for v in range(len(V))]
N = [[{'n': np.zeros((0, 2), dtype=np.int32),
       'q': np.zeros(0, dtype=np.int32),
       't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))] for _ in range(T)]

transitions = [[] for _ in V]
rewards = []

for t in range(T):
    print(f"t = {t}, thread = {Times_test[t][0:2]}", end='\t')
    v_src, v_dst, dt = Times_test[t]

    route = []
    v = v_src
    while v != v_dst:
        route.append(v)

        # Формирование состояния для подачи на вход нейронке:
        # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
        OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[t][v]['n']], axis=0)
        #state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, np.concatenate(L)])                                   ####################
        state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, L[v]])

        # Выбор действия жадно
        E_valid = find_next_vertices(paths[v_src][v_dst], route)
        action = agents[v].get_action(state, E_v[v], E_valid)

        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        add_thread_N(N[t][v], v_src, v_dst, action, dt)

        # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
        L[v] = calculate_queues_load(N[t], v)

        v = E_v[v][action]

    # Расчет награды и возвращение ее в переходы всем агентам
    reward = get_reward(L)
    print(f"reward = {round(reward, 4)}", end='\t')
    print(f"route = {route}", end='\t')
    rewards.append(reward)

    # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
    update_N(N[t])

    L = [calculate_queues_load(N[t], v) for v in V]

    if t < T - 1:
        N[t + 1] = copy.deepcopy(N[t])
    print()

print(f"\nreward = {sum(rewards) / T}\n")
# Out:
# t = 0, thread = [6 3]	reward = 0.9862	route = [6, 4]
# t = 1, thread = [4 6]	reward = 0.9849	route = [4]
# t = 2, thread = [2 4]	reward = 0.9839	route = [2, 3]
# t = 3, thread = [4 6]	reward = 0.9585	route = [4]
# t = 4, thread = [1 2]	reward = 0.9585	route = [1, 4, 7]
# t = 5, thread = [6 2]	reward = 0.9672	route = [6, 5, 0, 1]
# t = 6, thread = [2 4]	reward = 0.9679	route = [2, 3]
# t = 7, thread = [3 2]	reward = 0.99	route = [3]
# t = 8, thread = [5 4]	reward = 0.99	route = [5]
# t = 9, thread = [1 3]	reward = 0.9684	route = [1, 2, 7, 4]
# t = 10, thread = [5 0]	reward = 0.968	route = [5]
# t = 11, thread = [1 3]	reward = 0.9586	route = [1, 0, 5, 6, 4, 7, 2]
# t = 12, thread = [4 0]	reward = 0.9578	route = [4, 1]
# t = 13, thread = [3 1]	reward = 0.9857	route = [3, 2]
# t = 14, thread = [5 4]	reward = 0.9858	route = [5]
# t = 15, thread = [3 0]	reward = 0.9946	route = [3, 2, 1]
# t = 16, thread = [0 2]	reward = 0.9878	route = [0, 1]
# t = 17, thread = [2 6]	reward = 0.9885	route = [2, 7, 4, 1, 0, 5]
# t = 18, thread = [1 3]	reward = 0.9684	route = [1, 4, 7, 2]
# t = 19, thread = [3 6]	reward = 0.9689	route = [3, 4]
# t = 20, thread = [4 5]	reward = 0.9691	route = [4, 3, 2, 1, 0]
# t = 21, thread = [6 5]	reward = 0.9678	route = [6]
# t = 22, thread = [2 3]	reward = 0.9674	route = [2, 7, 4]
# t = 23, thread = [6 3]	reward = 0.9731	route = [6, 4]
# t = 24, thread = [0 2]	reward = 0.9476	route = [0, 1, 4, 3]
# t = 25, thread = [4 2]	reward = 0.9458	route = [4, 7]
# t = 26, thread = [6 4]	reward = 0.9681	route = [6, 5]
# t = 27, thread = [0 6]	reward = 0.9752	route = [0, 5]
# t = 28, thread = [1 3]	reward = 0.9028	route = [1, 0, 5, 6, 4]
# t = 29, thread = [0 3]	reward = 0.9646	route = [0, 1, 4, 7, 2]
# t = 30, thread = [5 1]	reward = 0.9675	route = [5, 4]
# t = 31, thread = [1 0]	reward = 0.9886	route = [1]
# t = 32, thread = [1 4]	reward = 0.9869	route = [1]
# t = 33, thread = [1 3]	reward = 0.9743	route = [1, 2]
# t = 34, thread = [3 6]	reward = 0.9743	route = [3, 4]
# t = 35, thread = [3 6]	reward = 0.9577	route = [3, 4, 1, 0, 5]
# t = 36, thread = [3 4]	reward = 0.9583	route = [3]
# t = 37, thread = [6 2]	reward = 0.954	route = [6, 4, 7]
# t = 38, thread = [5 0]	reward = 0.9613	route = [5, 4, 1]
# t = 39, thread = [3 1]	reward = 0.97	route = [3, 2]
# t = 40, thread = [3 1]	reward = 0.9555	route = [3, 4]
# t = 41, thread = [5 0]	reward = 0.9547	route = [5, 4, 7, 2, 1]
# t = 42, thread = [5 1]	reward = 0.9551	route = [5, 0]
# t = 43, thread = [3 5]	reward = 0.9814	route = [3, 2, 7, 4, 1, 0]
# t = 44, thread = [4 6]	reward = 0.9918	route = [4]
# t = 45, thread = [3 4]	reward = 0.988	route = [3, 2, 7]
# t = 46, thread = [3 1]	reward = 0.9823	route = [3, 4]
# t = 47, thread = [1 5]	reward = 0.9809	route = [1, 4, 6]
# t = 48, thread = [3 5]	reward = 0.9858	route = [3, 2, 1, 0]
# t = 49, thread = [3 5]	reward = 0.9858	route = [3, 2, 1, 0]
# t = 50, thread = [5 6]	reward = 0.9856	route = [5, 4]
# t = 51, thread = [3 0]	reward = 0.9855	route = [3, 2, 7, 4, 5]
# t = 52, thread = [5 4]	reward = 0.9854	route = [5]
# t = 53, thread = [4 1]	reward = 0.9831	route = [4]
# t = 54, thread = [6 4]	reward = 0.978	route = [6]
# t = 55, thread = [1 0]	reward = 0.9832	route = [1]
# t = 56, thread = [5 2]	reward = 0.9928	route = [5, 6, 4, 1]
# t = 57, thread = [3 4]	reward = 0.9655	route = [3, 2, 7]
# t = 58, thread = [0 4]	reward = 0.9905	route = [0, 5]
# t = 59, thread = [6 4]	reward = 0.9812	route = [6]
# t = 60, thread = [1 6]	reward = 0.9827	route = [1, 4, 5]
# t = 61, thread = [6 0]	reward = 0.9825	route = [6, 5]
# t = 62, thread = [0 3]	reward = 0.9593	route = [0, 1, 2, 7, 4]
# t = 63, thread = [6 2]	reward = 0.9563	route = [6, 4, 7]
# t = 64, thread = [2 0]	reward = 0.9693	route = [2, 7, 4, 1]
# t = 65, thread = [3 0]	reward = 0.9651	route = [3, 2, 1, 4, 6, 5]
# t = 66, thread = [0 2]	reward = 0.9724	route = [0, 1]
# t = 67, thread = [4 1]	reward = 0.9605	route = [4]
# t = 68, thread = [6 1]	reward = 0.9806	route = [6, 4, 3, 2]
# t = 69, thread = [0 3]	reward = 0.9789	route = [0, 5, 6, 4, 7, 2]
# t = 70, thread = [6 0]	reward = 0.9803	route = [6, 5]
# t = 71, thread = [3 1]	reward = 0.9752	route = [3, 2]
# t = 72, thread = [0 6]	reward = 0.9746	route = [0, 5, 4]
# t = 73, thread = [6 5]	reward = 0.9829	route = [6]
# t = 74, thread = [4 2]	reward = 0.9732	route = [4, 3]
# t = 75, thread = [3 5]	reward = 0.9761	route = [3, 4, 1, 0]
# t = 76, thread = [6 5]	reward = 0.9732	route = [6]
# t = 77, thread = [0 2]	reward = 0.9716	route = [0, 1, 4, 7]
# t = 78, thread = [4 6]	reward = 0.9834	route = [4]
# t = 79, thread = [5 2]	reward = 0.9929	route = [5, 6, 4, 1]
# t = 80, thread = [0 4]	reward = 0.9929	route = [0, 5]
# t = 81, thread = [1 6]	reward = 0.9985	route = [1, 0, 5]
# t = 82, thread = [6 5]	reward = 0.9861	route = [6]
# t = 83, thread = [6 2]	reward = 0.9688	route = [6, 4, 7]
# t = 84, thread = [0 6]	reward = 0.9688	route = [0, 5, 4]
# t = 85, thread = [6 1]	reward = 0.9649	route = [6, 5, 0]
# t = 86, thread = [1 3]	reward = 0.963	route = [1, 0, 5, 4]
# t = 87, thread = [4 2]	reward = 0.9631	route = [4, 7]
# t = 88, thread = [0 2]	reward = 0.8927	route = [0, 5, 4, 3]
# t = 89, thread = [0 3]	reward = 0.8942	route = [0, 1, 4, 7, 2]
# t = 90, thread = [4 3]	reward = 0.8826	route = [4, 7, 2]
# t = 91, thread = [5 4]	reward = 0.9819	route = [5]
# t = 92, thread = [0 2]	reward = 0.9784	route = [0, 1, 4, 3]
# t = 93, thread = [4 6]	reward = 0.9783	route = [4]
# t = 94, thread = [2 4]	reward = 0.9788	route = [2, 7]
# t = 95, thread = [3 4]	reward = 0.9792	route = [3]
# t = 96, thread = [6 2]	reward = 0.9716	route = [6, 4, 1]
# t = 97, thread = [2 5]	reward = 0.9697	route = [2, 7, 4, 6]
# t = 98, thread = [3 1]	reward = 0.9824	route = [3, 2]
# t = 99, thread = [1 4]	reward = 0.9823	route = [1]
#
# reward = 0.9715538398310116

# %% [markdown]
# #Анализ

# %%
# Анализ маршрутов и наград в фиксированный момент времени t (Необходима сформированный список N[t])
t = 88
v_src, v_dst = Times_test[t][0:2]

print(f't = {t}. Поток = ({v_src} -> {v_dst}), dt = {dt}, L = {round(λ[v_src, v_dst] / μ, 3)}')

rewards_t = []
for path in paths[v_src][v_dst]:
    N_t = copy.deepcopy(N[t - 1]) # N до прихода t-го потока

    for k in range(len(path) - 1):
        # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
        v = path[k]
        action = E_v[v].index(path[k + 1])
        add_thread_N(N_t[v], v_src, v_dst, action, dt)

    L = [calculate_queues_load(N_t, v) for v in V]

    # Расчет наград
    reward = get_reward(L)
    rewards_t.append(reward)
    print(f"route = {str(path):25}", end='\t')
    print(f"reward = {round(reward, 4)}")

print(f"Полученный reward = {round(rewards[t], 4)};")
print(f"Недополученный reward = {round(max(rewards_t) - rewards[t], 4)}\n")

visualize(G, N_t, Times_test[t][:2])
# Out:
# t = 88. Поток = (0 -> 2), dt = 4, L = 0.365
# route = [0, 1, 2]                	reward = 0.9625
# route = [0, 1, 4, 3, 2]          	reward = 0.9301
# route = [0, 1, 4, 7, 2]          	reward = 0.909
# route = [0, 5, 4, 1, 2]          	reward = 0.9092
# route = [0, 5, 4, 3, 2]          	reward = 0.8927
# route = [0, 5, 4, 7, 2]          	reward = 0.8791
# route = [0, 5, 6, 4, 1, 2]       	reward = 0.931
# route = [0, 5, 6, 4, 3, 2]       	reward = 0.9098
# route = [0, 5, 6, 4, 7, 2]       	reward = 0.8934
# Полученный reward = 0.8927;
# Недополученный reward = 0.0697
#
# Текущие потоки в сети:
# Поток = (0 -> 2), L = 0.041
# Поток = (1 -> 3), L = 0.083
# Поток = (4 -> 2), L = 0.083
# Поток = (6 -> 1), L = 0.002
#
# Выделенный поток = (0 -> 2), L = 0.041
# L_mean = 0.0585, reward = 0.8934

# %%
# Недополученные награды на каждом шаге t
# Выводит разность между максимально возможной и реально полученной наградой на каждом шаге t
print('t\tmax-min\tmax-current')

lost_rewards = []     # (max - current) - недополученная награда на каждом шаге
for t in range(1, T):
    v_src, v_dst = Times_test[t][0:2]

    rewards_t = []
    for path in paths[v_src][v_dst]:
        N_t = copy.deepcopy(N[t - 1]) # N до прихода t-го потока

        for k in range(len(path) - 1):
            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            v = path[k]
            action = E_v[v].index(path[k + 1])
            add_thread_N(N_t[v], v_src, v_dst, action, dt)

        L = [calculate_queues_load(N_t, v) for v in V]

        rewards_t.append(get_reward(L))

    lost_rewards.append(max(rewards_t) - rewards[t])
    print(f"{str(t)}\t{round(max(rewards_t) - min(rewards_t), 4)}\t{round(max(rewards_t) - rewards[t], 4)}")
# Out:
# t	max-min	max-current
# 1	0.033	0.0
# 2	0.0269	0.0
# 3	0.0301	0.0241
# 4	0.0002	0.0
# 5	0.0638	0.0
# 6	0.017	0.0009
# 7	0.0074	0.0
# 8	0.009	0.0002
# 9	0.041	0.0064
# 10	0.0032	0.0001
# 11	0.117	0.0015
# 12	0.0025	0.0009
# 13	0.0106	0.0
# 14	0.0001	0.0001
# 15	0.0017	0.0
# 16	0.0219	0.0
# 17	0.0006	0.0
# 18	0.0526	0.0067
# 19	0.0466	0.0
# 20	0.0048	0.0
# 21	0.0782	0.0
# 22	0.0103	0.0006
# 23	0.0474	0.0052
# 24	0.0487	0.0313
# 25	0.079	0.0
# 26	0.0383	0.0
# 27	0.0017	0.0
# 28	0.0737	0.0653
# 29	0.0664	0.0
# 30	0.0445	0.0
# 31	0.0185	0.0
# 32	0.0448	0.0
# 33	0.0505	0.0
# 34	0.024	0.0005
# 35	0.0378	0.0266
# 36	0.0486	0.01
# 37	0.0351	0.0
# 38	0.007	0.0004
# 39	0.0729	0.0
# 40	0.0337	0.0003
# 41	0.0017	0.0008
# 42	0.0213	0.0
# 43	0.0026	0.0009
# 44	0.0132	0.0
# 45	0.0066	0.0027
# 46	0.0729	0.0
# 47	0.0089	0.0038
# 48	0.0024	0.0
# 49	0.0024	0.0
# 50	0.0111	0.0003
# 51	0.0303	0.0
# 52	0.009	0.0004
# 53	0.0437	0.0
# 54	0.0482	0.0
# 55	0.0238	0.0
# 56	0.0003	0.0
# 57	0.0261	0.0261
# 58	0.0043	0.0001
# 59	0.0548	0.0
# 60	0.003	0.0001
# 61	0.0366	0.0
# 62	0.0354	0.0228
# 63	0.0643	0.0
# 64	0.0056	0.0038
# 65	0.0312	0.0047
# 66	0.0784	0.0
# 67	0.0777	0.0
# 68	0.0079	0.0
# 69	0.044	0.0011
# 70	0.0408	0.0
# 71	0.0406	0.0074
# 72	0.0003	0.0002
# 73	0.0752	0.0
# 74	0.0554	0.0
# 75	0.0017	0.0
# 76	0.0811	0.0
# 77	0.0628	0.0006
# 78	0.0429	0.0
# 79	0.0	0.0
# 80	0.0	0.0
# 81	0.0014	0.0009
# 82	0.0287	0.0
# 83	0.0508	0.0
# 84	0.0	0.0
# 85	0.0107	0.0001
# 86	0.0101	0.0056
# 87	0.0505	0.0
# 88	0.0833	0.0697
# 89	0.0741	0.0
# 90	0.0356	0.0085
# 91	0.0079	0.0002
# 92	0.0542	0.0013
# 93	0.0448	0.0003
# 94	0.0259	0.0013
# 95	0.0311	0.0
# 96	0.0936	0.0
# 97	0.0043	0.0013
# 98	0.0445	0.0
# 99	0.0102	0.0

# %%
lost_rewards_percent = np.cumsum(lost_rewards) / T / (max_reward - min_reward)

plt.title('Недополученная масштабированная награда')
plt.xlabel('t')
plt.ylabel('max_r(t) - r(t)')
plt.grid()
plt.ylim([0, 0.05])
plt.plot(np.arange(T - 1), lost_rewards_percent)
plt.show()

# %%
# Максимальный reward (субоптимальный), если выбирать оптимальные действия на каждом шаге (с подробным выводом)
max_reward = get_max_min_optimal_reward(Times_test, 'argmax', verbose=True) / T
print(f"\nmax reward = {max_reward}")
# Out:
# t = 0	 reward = 0.986	 route = [6, 4, 3]
# t = 1	 reward = 0.985	 route = [4, 6]
# t = 2	 reward = 0.984	 route = [2, 1, 4]
# t = 3	 reward = 0.983	 route = [4, 5, 6]
# t = 4	 reward = 0.983	 route = [1, 0, 5, 4, 7, 2]
# t = 5	 reward = 0.967	 route = [6, 5, 0, 1, 2]
# t = 6	 reward = 0.969	 route = [2, 1, 0, 5, 4]
# t = 7	 reward = 0.987	 route = [3, 4, 6, 5, 0, 1, 2]
# t = 8	 reward = 0.987	 route = [5, 0, 1, 2, 7, 4]
# t = 9	 reward = 0.976	 route = [1, 4, 3]
# t = 10	 reward = 0.976	 route = [5, 6, 4, 7, 2, 1, 0]
# t = 11	 reward = 0.96	 route = [1, 2, 3]
# t = 12	 reward = 0.96	 route = [4, 7, 2, 1, 0]
# t = 13	 reward = 0.986	 route = [3, 4, 1]
# t = 14	 reward = 0.986	 route = [5, 0, 1, 2, 7, 4]
# t = 15	 reward = 0.993	 route = [3, 4, 1, 0]
# t = 16	 reward = 0.985	 route = [0, 5, 4, 3, 2]
# t = 17	 reward = 0.985	 route = [2, 1, 4, 5, 6]
# t = 18	 reward = 0.964	 route = [1, 2, 3]
# t = 19	 reward = 0.965	 route = [3, 4, 6]
# t = 20	 reward = 0.965	 route = [4, 3, 2, 1, 0, 5]
# t = 21	 reward = 0.974	 route = [6, 5]
# t = 22	 reward = 0.974	 route = [2, 1, 0, 5, 6, 4, 3]
# t = 23	 reward = 0.972	 route = [6, 4, 1, 2, 3]
# t = 24	 reward = 0.977	 route = [0, 1, 4, 3, 2]
# t = 25	 reward = 0.973	 route = [4, 7, 2]
# t = 26	 reward = 0.968	 route = [6, 5, 4]
# t = 27	 reward = 0.973	 route = [0, 1, 4, 5, 6]
# t = 28	 reward = 0.966	 route = [1, 4, 3]
# t = 29	 reward = 0.97	 route = [0, 5, 6, 4, 1, 2, 3]
# t = 30	 reward = 0.977	 route = [5, 4, 7, 2, 1]
# t = 31	 reward = 0.989	 route = [1, 4, 6, 5, 0]
# t = 32	 reward = 0.981	 route = [1, 2, 3, 4]
# t = 33	 reward = 0.968	 route = [1, 0, 5, 6, 4, 3]
# t = 34	 reward = 0.964	 route = [3, 2, 7, 4, 6]
# t = 35	 reward = 0.959	 route = [3, 2, 1, 0, 5, 6]
# t = 36	 reward = 0.969	 route = [3, 2, 7, 4]
# t = 37	 reward = 0.965	 route = [6, 4, 7, 2]
# t = 38	 reward = 0.962	 route = [5, 0]
# t = 39	 reward = 0.97	 route = [3, 4, 1]
# t = 40	 reward = 0.957	 route = [3, 2, 1]
# t = 41	 reward = 0.957	 route = [5, 0]
# t = 42	 reward = 0.957	 route = [5, 0, 1]
# t = 43	 reward = 0.984	 route = [3, 2, 1, 4, 6, 5]
# t = 44	 reward = 0.99	 route = [4, 6]
# t = 45	 reward = 0.989	 route = [3, 4]
# t = 46	 reward = 0.981	 route = [3, 2, 1]
# t = 47	 reward = 0.985	 route = [1, 2, 3, 4, 5]
# t = 48	 reward = 0.986	 route = [3, 4, 5]
# t = 49	 reward = 0.986	 route = [3, 4, 1, 0, 5]
# t = 50	 reward = 0.986	 route = [5, 0, 1, 4, 6]
# t = 51	 reward = 0.984	 route = [3, 4, 1, 0]
# t = 52	 reward = 0.985	 route = [5, 6, 4]
# t = 53	 reward = 0.974	 route = [4, 3, 2, 1]
# t = 54	 reward = 0.969	 route = [6, 5, 4]
# t = 55	 reward = 0.976	 route = [1, 2, 7, 4, 5, 0]
# t = 56	 reward = 0.984	 route = [5, 6, 4, 3, 2]
# t = 57	 reward = 0.988	 route = [3, 2, 1, 4]
# t = 58	 reward = 0.988	 route = [0, 5, 6, 4]
# t = 59	 reward = 0.978	 route = [6, 5, 4]
# t = 60	 reward = 0.978	 route = [1, 2, 3, 4, 5, 6]
# t = 61	 reward = 0.977	 route = [6, 4, 1, 0]
# t = 62	 reward = 0.978	 route = [0, 1, 2, 7, 4, 3]
# t = 63	 reward = 0.972	 route = [6, 5, 4, 7, 2]
# t = 64	 reward = 0.971	 route = [2, 3, 4, 5, 0]
# t = 65	 reward = 0.972	 route = [3, 2, 1, 4, 5, 0]
# t = 66	 reward = 0.97	 route = [0, 5, 6, 4, 1, 2]
# t = 67	 reward = 0.942	 route = [4, 3, 2, 1]
# t = 68	 reward = 0.971	 route = [6, 5, 0, 1]
# t = 69	 reward = 0.973	 route = [0, 1, 4, 7, 2, 3]
# t = 70	 reward = 0.973	 route = [6, 5, 4, 1, 0]
# t = 71	 reward = 0.982	 route = [3, 2, 1]
# t = 72	 reward = 0.982	 route = [0, 5, 4, 6]
# t = 73	 reward = 0.984	 route = [6, 5]
# t = 74	 reward = 0.973	 route = [4, 1, 2]
# t = 75	 reward = 0.976	 route = [3, 4, 7, 2, 1, 0, 5]
# t = 76	 reward = 0.973	 route = [6, 5]
# t = 77	 reward = 0.972	 route = [0, 1, 4, 3, 2]
# t = 78	 reward = 0.983	 route = [4, 6]
# t = 79	 reward = 0.993	 route = [5, 0, 1, 4, 7, 2]
# t = 80	 reward = 0.993	 route = [0, 1, 2, 3, 4]
# t = 81	 reward = 0.999	 route = [1, 0, 5, 6]
# t = 82	 reward = 0.986	 route = [6, 5]
# t = 83	 reward = 0.969	 route = [6, 4, 1, 2]
# t = 84	 reward = 0.97	 route = [0, 5, 6]
# t = 85	 reward = 0.966	 route = [6, 5, 4, 7, 2, 1]
# t = 86	 reward = 0.969	 route = [1, 2, 3]
# t = 87	 reward = 0.968	 route = [4, 3, 2]
# t = 88	 reward = 0.965	 route = [0, 5, 6, 4, 7, 2]
# t = 89	 reward = 0.971	 route = [0, 1, 4, 3]
# t = 90	 reward = 0.953	 route = [4, 3]
# t = 91	 reward = 0.989	 route = [5, 0, 1, 2, 3, 4]
# t = 92	 reward = 0.982	 route = [0, 5, 4, 7, 2]
# t = 93	 reward = 0.982	 route = [4, 6]
# t = 94	 reward = 0.982	 route = [2, 1, 4]
# t = 95	 reward = 0.982	 route = [3, 2, 7, 4]
# t = 96	 reward = 0.972	 route = [6, 4, 1, 2]
# t = 97	 reward = 0.971	 route = [2, 3, 4, 5]
# t = 98	 reward = 0.985	 route = [3, 2, 1]
# t = 99	 reward = 0.982	 route = [1, 4]
#
# max reward = 0.9759624377243478

# %%
# Минимальный reward (субоптимальный), если выбирать оптимальные действия на каждом шаге (с подробным выводом)
min_reward = get_max_min_optimal_reward(Times_test, 'argmin', verbose=True) / T
print(f"\nmin reward = {min_reward}")
# Out:
# t = 0	 reward = 0.978	 route = [6, 5, 0, 1, 2, 7, 4, 3]
# t = 1	 reward = 0.952	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 2	 reward = 0.929	 route = [2, 1, 0, 5, 6, 4]
# t = 3	 reward = 0.827	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 4	 reward = 0.883	 route = [1, 0, 5, 6, 4, 3, 2]
# t = 5	 reward = 0.842	 route = [6, 5, 0, 1, 4, 3, 2]
# t = 6	 reward = 0.839	 route = [2, 1, 4]
# t = 7	 reward = 0.962	 route = [3, 2]
# t = 8	 reward = 0.96	 route = [5, 6, 4]
# t = 9	 reward = 0.871	 route = [1, 0, 5, 6, 4, 3]
# t = 10	 reward = 0.939	 route = [5, 6, 4, 3, 2, 1, 0]
# t = 11	 reward = 0.8	 route = [1, 0, 5, 6, 4, 3]
# t = 12	 reward = 0.796	 route = [4, 3, 2, 1, 0]
# t = 13	 reward = 0.974	 route = [3, 2, 7, 4, 6, 5, 0, 1]
# t = 14	 reward = 0.959	 route = [5, 0, 1, 2, 7, 4]
# t = 15	 reward = 0.986	 route = [3, 2, 7, 4, 5, 0]
# t = 16	 reward = 0.954	 route = [0, 1, 4, 3, 2]
# t = 17	 reward = 0.973	 route = [2, 1, 4, 6]
# t = 18	 reward = 0.893	 route = [1, 4, 3]
# t = 19	 reward = 0.919	 route = [3, 2, 1, 4, 6]
# t = 20	 reward = 0.918	 route = [4, 3, 2, 1, 0, 5]
# t = 21	 reward = 0.861	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 22	 reward = 0.848	 route = [2, 1, 4, 3]
# t = 23	 reward = 0.873	 route = [6, 4, 3]
# t = 24	 reward = 0.811	 route = [0, 5, 6, 4, 3, 2]
# t = 25	 reward = 0.838	 route = [4, 3, 2]
# t = 26	 reward = 0.905	 route = [6, 4]
# t = 27	 reward = 0.932	 route = [0, 5, 6]
# t = 28	 reward = 0.854	 route = [1, 0, 5, 6, 4, 3]
# t = 29	 reward = 0.854	 route = [0, 5, 6, 4, 3]
# t = 30	 reward = 0.841	 route = [5, 6, 4, 3, 2, 1]
# t = 31	 reward = 0.961	 route = [1, 0]
# t = 32	 reward = 0.934	 route = [1, 0, 5, 6, 4]
# t = 33	 reward = 0.807	 route = [1, 0, 5, 6, 4, 3]
# t = 34	 reward = 0.763	 route = [3, 4, 1, 0, 5, 6]
# t = 35	 reward = 0.825	 route = [3, 4, 1, 0, 5, 6]
# t = 36	 reward = 0.826	 route = [3, 2, 1, 0, 5, 6, 4]
# t = 37	 reward = 0.8	 route = [6, 4, 1, 2]
# t = 38	 reward = 0.901	 route = [5, 6, 4, 1, 0]
# t = 39	 reward = 0.897	 route = [3, 2, 7, 4, 1]
# t = 40	 reward = 0.867	 route = [3, 2, 7, 4, 1]
# t = 41	 reward = 0.862	 route = [5, 4, 3, 2, 1, 0]
# t = 42	 reward = 0.842	 route = [5, 6, 4, 3, 2, 1]
# t = 43	 reward = 0.95	 route = [3, 2, 7, 4, 1, 0, 5]
# t = 44	 reward = 0.936	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 45	 reward = 0.864	 route = [3, 2, 1, 0, 5, 6, 4]
# t = 46	 reward = 0.809	 route = [3, 2, 1]
# t = 47	 reward = 0.92	 route = [1, 0, 5]
# t = 48	 reward = 0.983	 route = [3, 2, 1, 4, 5]
# t = 49	 reward = 0.981	 route = [3, 2, 1, 4, 6, 5]
# t = 50	 reward = 0.981	 route = [5, 6]
# t = 51	 reward = 0.946	 route = [3, 2, 1, 0]
# t = 52	 reward = 0.95	 route = [5, 4]
# t = 53	 reward = 0.939	 route = [4, 3, 2, 1]
# t = 54	 reward = 0.934	 route = [6, 5, 4]
# t = 55	 reward = 0.941	 route = [1, 4, 6, 5, 0]
# t = 56	 reward = 0.989	 route = [5, 0, 1, 4, 3, 2]
# t = 57	 reward = 0.959	 route = [3, 2, 1, 4]
# t = 58	 reward = 0.958	 route = [0, 1, 4]
# t = 59	 reward = 0.871	 route = [6, 5, 0, 1, 4]
# t = 60	 reward = 0.918	 route = [1, 4, 6]
# t = 61	 reward = 0.899	 route = [6, 5, 0]
# t = 62	 reward = 0.856	 route = [0, 1, 4, 3]
# t = 63	 reward = 0.843	 route = [6, 5, 0, 1, 4, 3, 2]
# t = 64	 reward = 0.855	 route = [2, 1, 4, 6, 5, 0]
# t = 65	 reward = 0.814	 route = [3, 2, 1, 4, 6, 5, 0]
# t = 66	 reward = 0.82	 route = [0, 1, 4, 3, 2]
# t = 67	 reward = 0.752	 route = [4, 6, 5, 0, 1]
# t = 68	 reward = 0.917	 route = [6, 5, 0, 1]
# t = 69	 reward = 0.873	 route = [0, 1, 4, 3]
# t = 70	 reward = 0.893	 route = [6, 5, 0]
# t = 71	 reward = 0.914	 route = [3, 4, 6, 5, 0, 1]
# t = 72	 reward = 0.937	 route = [0, 1, 2, 3, 4, 6]
# t = 73	 reward = 0.947	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 74	 reward = 0.892	 route = [4, 3, 2]
# t = 75	 reward = 0.974	 route = [3, 2, 1, 0, 5]
# t = 76	 reward = 0.889	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 77	 reward = 0.814	 route = [0, 5, 6, 4, 3, 2]
# t = 78	 reward = 0.917	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 79	 reward = 0.982	 route = [5, 6, 4, 3, 2]
# t = 80	 reward = 0.979	 route = [0, 5, 6, 4]
# t = 81	 reward = 0.998	 route = [1, 0, 5, 6]
# t = 82	 reward = 0.955	 route = [6, 4, 3, 2, 1, 0, 5]
# t = 83	 reward = 0.868	 route = [6, 4, 3, 2]
# t = 84	 reward = 0.868	 route = [0, 5, 4, 6]
# t = 85	 reward = 0.846	 route = [6, 4, 3, 2, 1]
# t = 86	 reward = 0.844	 route = [1, 0, 5, 6, 4, 3]
# t = 87	 reward = 0.897	 route = [4, 3, 2]
# t = 88	 reward = 0.817	 route = [0, 5, 6, 4, 3, 2]
# t = 89	 reward = 0.788	 route = [0, 5, 6, 4, 3]
# t = 90	 reward = 0.778	 route = [4, 3]
# t = 91	 reward = 0.989	 route = [5, 4]
# t = 92	 reward = 0.944	 route = [0, 5, 4, 3, 2]
# t = 93	 reward = 0.884	 route = [4, 3, 2, 1, 0, 5, 6]
# t = 94	 reward = 0.853	 route = [2, 1, 0, 5, 4]
# t = 95	 reward = 0.788	 route = [3, 2, 1, 0, 5, 4]
# t = 96	 reward = 0.735	 route = [6, 5, 4, 3, 2]
# t = 97	 reward = 0.797	 route = [2, 1, 0, 5]
# t = 98	 reward = 0.926	 route = [3, 2, 1]
# t = 99	 reward = 0.969	 route = [1, 0, 5, 6, 4]
#
# min reward = 0.8919704050626504

# %%
# Пример использования визуализации
visualize(G, N[5], [4, 6])
# Out:
# Текущие потоки в сети:
# Поток = (1 -> 2), L = 0.0
# Поток = (4 -> 6), L = 0.034
# Поток = (6 -> 2), L = 0.083
# Поток = (6 -> 3), L = 0.048
#
# Выделенный поток = (4 -> 6), L = 0.034
# L_mean = 0.021, reward = 0.9672

# %% [markdown]
# # График L(ρ,S)

# %%
s = 5
ρ = np.linspace(0, 5, 100)

L = loading_queue(ρ, s) / s

# %%
plt.plot(ρ, L)

plt.xlabel('ρ')
plt.ylabel('L(ρ, S) / S')

plt.xlim(0, s)
plt.ylim(0, 1)

plt.grid()
plt.show()

# %% [markdown]
# # Сравнение

# %%
with open('/content/drive/MyDrive/marl/2/lost_rewards.pickle', 'rb') as f:
   lost_rewards_easy = pickle.load(f)

# %%
lost_rewards_hard = lost_rewards_percent

plt.title('Недополученная масштабированная награда')
plt.xlabel('t')
plt.ylabel('max_r(t) - r(t)')
plt.grid()
plt.ylim([0, 0.05])
plt.plot(np.arange(T - 1), lost_rewards_hard, label='Без централизованного знания сети')
plt.plot(np.arange(T - 1), lost_rewards_easy, label='С централизованным знанием сети')
plt.legend()
plt.show()

# %%
with open(f'{PATH}lost_rewards.pickle', 'wb') as f:
   pickle.dump(lost_rewards_hard, f)

# %% [markdown]
# # Проверка гипотезы (hard)

# %%
# Загрузка сохраненных моделей и параметров оптимизаторов
PATH = '/content/drive/MyDrive/marl/3/'

for v in V:
    agents[v].load_state_dict(torch.load(PATH + f'model_{v}'))
    optimizers[v].load_state_dict(torch.load(PATH + f'opt_{v}'))

# %%
seed_rewards = []

for seed in range(225):

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    T = 100
    Times_test = generate_treads(T)

    # Создает массив N(t), сохраняющий поступающие потоки в каждый момент времени t, для анализа
    L = [np.zeros(len(E_v[v])) for v in range(len(V))]
    N = [[{'n': np.zeros((0, 2), dtype=np.int32),
          'q': np.zeros(0, dtype=np.int32),
          't': np.zeros(0, dtype=np.int32)} for _ in range(len(V))] for _ in range(T)]

    transitions = [[] for _ in V]
    rewards = []

    for t in range(T):
        v_src, v_dst, dt = Times_test[t]

        route = []
        v = v_src
        while v != v_dst:
            route.append(v)

            # Формирование состояния для подачи на вход нейронке:
            # OHE поступающего потока | Sum всех OHE поступающих потоков на коммутатор | Загруженность во всей сети L
            OHE_threads = np.zeros(2 * len(V)) + np.sum([OHE_thread(v_src, v_dst) for (v_src, v_dst) in N[t][v]['n']], axis=0)
            state = np.concatenate([OHE_thread(v_src, v_dst), OHE_threads, L[v]])

            # Выбор действия жадно
            E_valid = find_next_vertices(paths[v_src][v_dst], route)
            action = agents[v].get_action(state, E_v[v], E_valid)

            # Добавление нового потока с его характеристиками [(v_src, v_dst), q, t]
            add_thread_N(N[t][v], v_src, v_dst, action, dt)

            # Рассчитывает загруженность L[v] для каждого выходного порта q коммутатора v
            L[v] = calculate_queues_load(N[t], v)

            v = E_v[v][action]

        # Расчет награды и возвращение ее в переходы всем агентам
        reward = get_reward(L)
        rewards.append(reward)

        # Уменьшение оставшегося времени dt и удаление из массивов потоков с (dt = 0)
        update_N(N[t])

        L = [calculate_queues_load(N[t], v) for v in V]

        if t < T - 1:
            N[t + 1] = copy.deepcopy(N[t])

    seed_rewards.append(sum(rewards) / T)

np.array(seed_rewards)
# Out:
# array([0.96361516, 0.96603615, 0.96572132, 0.9554362 , 0.97222452,
#        0.96576474, 0.96608355, 0.97079908, 0.96916452, 0.9615447 ,
#        0.96127004, 0.97136468, 0.95299942, 0.96001064, 0.96876546,
#        0.96832233, 0.96157038, 0.95874464, 0.96306414, 0.96059521,
#        0.97102778, 0.95972085, 0.96380955, 0.96956493, 0.9749985 ,
#        0.97532751, 0.96484549, 0.96644085, 0.96681643, 0.96033949,
#        0.96077531, 0.96556867, 0.97460918, 0.96352706, 0.97227697,
#        0.9573574 , 0.96851071, 0.97208429, 0.9600059 , 0.95941773,
#        0.97374131, 0.96901419, 0.97155384, 0.97110746, 0.9649371 ,
#        0.96196422, 0.97233491, 0.95946071, 0.96923094, 0.95607386,
#        0.95817206, 0.96815177, 0.96740087, 0.9687272 , 0.96661855,
#        0.96891403, 0.96545632, 0.96156428, 0.96842411, 0.96904636,
#        0.9609147 , 0.96415754, 0.96386332, 0.96745899, 0.97145722,
#        0.96959697, 0.96903977, 0.96733428, 0.96498789, 0.97193077,
#        0.96477221, 0.9709723 , 0.97336315, 0.96817577, 0.96970529,
#        0.96923534, 0.96140157, 0.9623202 , 0.96996949, 0.96593939,
#        0.96489428, 0.97344442, 0.96122758, 0.96290426, 0.96270713,
#        0.96389413, 0.968036  , 0.96885818, 0.95955241, 0.97485982,
#        0.96812724, 0.96746983, 0.95877613, 0.96735091, 0.97403411,
#        0.95724361, 0.97057751, 0.9712165 , 0.96631675, 0.96376645,
#        0.96683401, 0.96306224, 0.95600295, 0.96658149, 0.96846298,
#        0.97040475, 0.95995502, 0.96728685, 0.96710215, 0.96469969,
#        0.97244221, 0.96529516, 0.96723167, 0.97040492, 0.95997551,
#        0.96752819, 0.95794539, 0.9627555 , 0.9647343 , 0.96593947,
#        0.96977596, 0.96838492, 0.95831382, 0.96534202, 0.96440243,
#        0.96287553, 0.96300288, 0.95927712, 0.96280502, 0.96518671,
#        0.96748147, 0.97208025, 0.96727142, 0.9644353 , 0.96051317,
#        0.96881942, 0.971242  , 0.97123414, 0.96319685, 0.97053182,
#        0.96324849, 0.95894769, 0.96279497, 0.96159599, 0.95730925,
#        0.96767165, 0.97164363, 0.97363526, 0.95967496, 0.96223062,
#        0.9673274 , 0.96874524, 0.9630999 , 0.9712299 , 0.97184437,
#        0.9574428 , 0.96415025, 0.97061424, 0.97226507, 0.96314586,
#        0.95649271, 0.96179687, 0.96505858, 0.9652396 , 0.97191348,
#        0.96729372, 0.96575711, 0.9624209 , 0.96050661, 0.96158304,
#        0.96842861, 0.97252343, 0.96913506, 0.96549665, 0.96407146,
#        0.96832628, 0.97273512, 0.97394713, 0.96819313, 0.95938725,
#        0.96062622, 0.96618973, 0.97141448, 0.96764791, 0.96452234,
#        0.96839186, 0.96761885, 0.96579424, 0.97318396, 0.97759954,
#        0.97007333, 0.96796596, 0.97042028, 0.97199168, 0.96779097,
#        0.9662846 , 0.9652367 , 0.964925  , 0.97705016, 0.96731495,
#        0.96982219, 0.96778916, 0.97493035, 0.96957119, 0.96842905,
#        0.97575935, 0.97172152, 0.96415536, 0.96487879, 0.97122942,
#        0.96780206, 0.9672745 , 0.97177626, 0.96315324, 0.96672949,
#        0.96690694, 0.96104004, 0.97042764, 0.97166047, 0.96840543,
#        0.96228347, 0.97100047, 0.97246535, 0.96459578, 0.97101985])

# %%
seed_rewards = np.array(seed_rewards)

np.mean(seed_rewards > 0.96)
# Out:
# 0.8933333333333333
